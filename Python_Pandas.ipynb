# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnaviPatil1111/Python/blob/main/Python_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Exploration Questions:**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## ***Questions on Sales Data for Pandas:***

# %%
import numpy as np
import pandas as pd

# %%
#1.	Load the sales data CSV file into a Pandas DataFrame.
df = pd.read_csv("/content/drive/MyDrive/Data Sets/sales_data.csv")
df
# Out:
#     EmployeeID         Name  Age   Department Region  SalesAmount  Target  \
# 0         1001   Employee_1   28  Electronics  North        34200   17968
# 1         1002   Employee_2   26   Home Decor   East        32850   42821
# 2         1003   Employee_3   22   Home Decor  South        43267   40728
# 3         1004   Employee_4   31  Electronics   West        17263   40183
# 4         1005   Employee_5   49    Groceries   East        37427   17010
# 5         1006   Employee_6   22    Groceries   East        25853   41898
# 6         1007   Employee_7   43   Automobile   West         7695   32586
# 7         1008   Employee_8   37    Groceries  South        47690   49267
# 8         1009   Employee_9   31   Home Decor   East        49578   22738
# 9         1010  Employee_10   52  Electronics   East        18766   14392
# 10        1011  Employee_11   46  Electronics   West        26253   49772
# 11        1012  Employee_12   43     Clothing  North        32197   47360
# ...

# %%
#2.	Display the first 5 rows of the DataFrame.
df.head(5)
# Out:
#    EmployeeID        Name  Age   Department Region  SalesAmount  Target  \
# 0        1001  Employee_1   28  Electronics  North        34200   17968
# 1        1002  Employee_2   26   Home Decor   East        32850   42821
# 2        1003  Employee_3   22   Home Decor  South        43267   40728
# 3        1004  Employee_4   31  Electronics   West        17263   40183
# 4        1005  Employee_5   49    Groceries   East        37427   17010
#
#   TargetAchieved  CommissionPercentage  TotalEarnings
# 0            Yes                     5       35910.00
# 1             No                     9       35806.50
# 2            Yes                     2       44132.34
# 3             No                     3       17780.89
# 4            Yes                     4       38924.08

# %%
#3.	Show the last 5 rows of the DataFrame.
df.tail(5)
# Out:
#     EmployeeID         Name  Age  Department Region  SalesAmount  Target  \
# 45        1046  Employee_46   51  Automobile  North        32685   48545
# 46        1047  Employee_47   31    Clothing   East        37045   10613
# 47        1048  Employee_48   35   Groceries   East        18960   12567
# 48        1049  Employee_49   43  Home Decor  South        17997   12104
# 49        1050  Employee_50   33  Automobile  North        27557   13555
#
#    TargetAchieved  CommissionPercentage  TotalEarnings
# 45             No                     2       33338.70
# 46            Yes                     9       40379.05
# 47            Yes                     8       20476.80
# 48            Yes                     5       18896.85
# 49            Yes                     5       28934.85

# %%
#4.	Get the shape (number of rows and columns) of the dataset.
df.shape
# Out:
# (50, 10)

# %%
#5.	Display summary statistics of all numerical columns.
# avg, max, min, std, 1st 2nd 3rd quarter value, count, sum

df.describe()
# Out:
#        EmployeeID        Age   SalesAmount        Target  \
# count    50.00000  50.000000     50.000000     50.000000
# mean   1025.50000  39.780000  29381.580000  29492.040000
# std      14.57738  10.525557  12096.724585  13022.222386
# min    1001.00000  22.000000   5377.000000  10151.000000
# 25%    1013.25000  31.000000  20736.500000  17249.500000
# 50%    1025.50000  41.000000  29747.000000  28675.000000
# 75%    1037.75000  49.000000  38276.750000  41410.500000
# max    1050.00000  55.000000  49578.000000  49772.000000
#
#        CommissionPercentage  TotalEarnings
# count             50.000000      50.000000
# mean               5.860000   31034.621800
# std                2.432853   12703.757127
# min                2.000000    5538.310000
# 25%                4.000000   22142.187500
# 50%                6.000000   31686.450000
# 75%                8.000000   40749.962500
# max               10.000000   52860.600000

# %%
#6.	Get column names of the dataset.
df.columns
# Out:
# Index(['EmployeeID', 'Name', 'Age', 'Department', 'Region', 'SalesAmount',
#        'Target', 'TargetAchieved', 'CommissionPercentage', 'TotalEarnings'],
#       dtype='object')

# %%
#7.	Check for missing values in the dataset.
df.isnull().sum()
# Out:
# EmployeeID              0
# Name                    0
# Age                     0
# Department              0
# Region                  0
# SalesAmount             0
# Target                  0
# TargetAchieved          0
# CommissionPercentage    0
# TotalEarnings           0
# dtype: int64

# %%
#8.	Get the data types of each column.
df.dtypes
# Out:
# EmployeeID                int64
# Name                     object
# Age                       int64
# Department               object
# Region                   object
# SalesAmount               int64
# Target                    int64
# TargetAchieved           object
# CommissionPercentage      int64
# TotalEarnings           float64
# dtype: object

# %%
#9.	Sort the dataset by SalesAmount in descending order.
df.sort_values(by='SalesAmount',ascending=False)
# Out:
#     EmployeeID         Name  Age   Department Region  SalesAmount  Target  \
# 8         1009   Employee_9   31   Home Decor   East        49578   22738
# 33        1034  Employee_34   42  Electronics   East        49111   31797
# 15        1016  Employee_16   22  Electronics   East        48945   44965
# 7         1008   Employee_8   37    Groceries  South        47690   49267
# 42        1043  Employee_43   33   Home Decor   West        46558   15582
# 40        1041  Employee_41   32   Automobile   East        44983   24131
# 2         1003   Employee_3   22   Home Decor  South        43267   40728
# 22        1023  Employee_23   47   Automobile   East        41728   19652
# 44        1045  Employee_45   53  Electronics   East        40454   19416
# 16        1017  Employee_17   23    Groceries   East        40326   47702
# 34        1035  Employee_35   41     Clothing  North        39717   12490
# 30        1031  Employee_31   40   Home Decor   West        38718   25399
# ...

# %%
#10.	Select only EmployeeID, Name, and SalesAmount columns.
df[['EmployeeID', 'Name', 'SalesAmount']]
# Out:
#     EmployeeID         Name  SalesAmount
# 0         1001   Employee_1        34200
# 1         1002   Employee_2        32850
# 2         1003   Employee_3        43267
# 3         1004   Employee_4        17263
# 4         1005   Employee_5        37427
# 5         1006   Employee_6        25853
# 6         1007   Employee_7         7695
# 7         1008   Employee_8        47690
# 8         1009   Employee_9        49578
# 9         1010  Employee_10        18766
# 10        1011  Employee_11        26253
# 11        1012  Employee_12        32197
# 12        1013  Employee_13         5955
# 13        1014  Employee_14        30025
# 14        1015  Employee_15         5377
# 15        1016  Employee_16        48945
# 16        1017  Employee_17        40326
# 17        1018  Employee_18        30349
# 18        1019  Employee_19        12766
# 19        1020  Employee_20        28150
# 20        1021  Employee_21        27366
# 21        1022  Employee_22         8939
# ...

# %%
#*Filtering & Conditional Selection ( SQL limit , Sort asc desc , Where )*
#11.	Find all employees who achieved their sales target.
df.head()
df['TargetAchieved']=='yes'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: TargetAchieved, dtype: bool

# %%
#12.	Find employees who belong to the "Electronics" department.
df['Department']=='Electronics'
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33     True
# 34    False
# 35    False
# 36    False
# 37     True
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44     True
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: Department, dtype: bool

# %%
#13.	Find employees who belong to the "West" region and achieved their target.
df['Region']=='West'
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12     True
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28     True
# 29     True
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# 35     True
# 36     True
# 37    False
# 38     True
# 39     True
# 40    False
# 41    False
# 42     True
# 43     True
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: Region, dtype: bool

# %%
#14.	Filter employees who have a SalesAmount greater than 30,000.
df['SalesAmount']>30000
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
# 5     False
# 6     False
# 7      True
# 8      True
# 9     False
# 10    False
# 11     True
# 12    False
# 13     True
# 14    False
# 15     True
# 16     True
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22     True
# 23     True
# 24    False
# 25    False
# 26     True
# 27     True
# 28    False
# 29    False
# 30     True
# 31     True
# 32    False
# 33     True
# 34     True
# 35    False
# 36    False
# 37    False
# 38     True
# 39    False
# 40     True
# 41    False
# 42     True
# 43    False
# 44     True
# 45     True
# 46     True
# 47    False
# 48    False
# 49    False
# Name: SalesAmount, dtype: bool

# %%
#15.	Find employees who have a commission percentage greater than 5%.
df.head()
df['CommissionPercentage'] > 5
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14    False
# 15     True
# 16     True
# 17    False
# 18     True
# 19    False
# 20    False
# 21     True
# 22     True
# 23    False
# 24     True
# 25     True
# 26     True
# 27    False
# 28     True
# 29     True
# 30     True
# 31    False
# 32    False
# 33     True
# 34    False
# 35     True
# 36     True
# 37     True
# 38     True
# 39    False
# 40    False
# 41     True
# 42     True
# 43     True
# 44    False
# 45    False
# 46     True
# 47     True
# 48    False
# 49    False
# Name: CommissionPercentage, dtype: bool

# %%
#16.	Find employees who did not achieve their target.
df['TargetAchieved'] == 'No'
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15    False
# 16     True
# 17    False
# 18     True
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24     True
# 25     True
# 26     True
# 27    False
# 28     True
# 29     True
# 30    False
# 31     True
# 32    False
# 33    False
# 34    False
# 35     True
# 36    False
# 37     True
# 38    False
# 39    False
# 40    False
# 41     True
# 42    False
# 43     True
# 44    False
# 45     True
# 46    False
# 47    False
# 48    False
# 49    False
# Name: TargetAchieved, dtype: bool

# %%
#17.	Find employees who belong to either "Groceries" or "Automobile" department.
df[(df['Department'] == 'Groceries') | (df['Department'] == 'Automobile')]
# Out:
#     EmployeeID         Name  Age  Department Region  SalesAmount  Target  \
# 4         1005   Employee_5   49   Groceries   East        37427   17010
# 5         1006   Employee_6   22   Groceries   East        25853   41898
# 6         1007   Employee_7   43  Automobile   West         7695   32586
# 7         1008   Employee_8   37   Groceries  South        47690   49267
# 14        1015  Employee_15   47   Groceries  South         5377   16274
# 16        1017  Employee_17   23   Groceries   East        40326   47702
# 18        1019  Employee_19   55  Automobile  North        12766   48762
# 19        1020  Employee_20   36  Automobile   West        28150   15865
# 21        1022  Employee_22   32   Groceries   East         8939   31223
# 22        1023  Employee_23   47  Automobile   East        41728   19652
# 23        1024  Employee_24   52  Automobile  North        36688   33729
# 25        1026  Employee_26   55  Automobile  South        21533   47125
# ...

# %%
#18.	Find employees with TotalEarnings greater than 40,000.
df['TotalEarnings'] > 40000
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22     True
# 23    False
# 24    False
# 25    False
# 26     True
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33     True
# 34     True
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40     True
# 41    False
# 42     True
# 43    False
# 44     True
# 45    False
# 46     True
# 47    False
# 48    False
# 49    False
# Name: TotalEarnings, dtype: bool

# %%
#19.	Find employees who are older than 40 years and achieved their target.
df.head()
df[(df['Age'] > 40) & (df['TargetAchieved'] == 'Yes')]
# Out:
#     EmployeeID         Name  Age   Department Region  SalesAmount  Target  \
# 4         1005   Employee_5   49    Groceries   East        37427   17010
# 9         1010  Employee_10   52  Electronics   East        18766   14392
# 20        1021  Employee_21   51     Clothing  North        27366   14747
# 22        1023  Employee_23   47   Automobile   East        41728   19652
# 23        1024  Employee_24   52   Automobile  North        36688   33729
# 32        1033  Employee_33   49     Clothing  North        29469   10151
# 33        1034  Employee_34   42  Electronics   East        49111   31797
# 34        1035  Employee_35   41     Clothing  North        39717   12490
# 38        1039  Employee_39   55     Clothing   West        35710   34422
# 39        1040  Employee_40   44   Automobile   West        27167   25440
# 44        1045  Employee_45   53  Electronics   East        40454   19416
# 48        1049  Employee_49   43   Home Decor  South        17997   12104
#
# ...

# %%
#20.	Select employees whose names contain "10".
df['Name'].str.contains('10')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: Name, dtype: bool

# %%
#Aggregation & Grouping (Pivot , Group by )
#21.	Find the average sales amount per department.
df.groupby('Department')['SalesAmount'].mean()
# Out:
# Department
# Automobile     26610.818182
# Clothing       26593.181818
# Electronics    32422.300000
# Groceries      27139.000000
# Home Decor     36027.750000
# Name: SalesAmount, dtype: float64

# %%
#22.	Count the number of employees in each region.
df.groupby('Region')['EmployeeID'].count()
# Out:
# Region
# East     16
# North    12
# South     6
# West     16
# Name: EmployeeID, dtype: int64

# %%
#23.	Find the highest SalesAmount in each department.
df.head()
df.groupby('Department')['SalesAmount'].max()
# Out:
# Department
# Automobile     44983
# Clothing       39717
# Electronics    49111
# Groceries      47690
# Home Decor     49578
# Name: SalesAmount, dtype: int64

# %%
#24.	Find the lowest SalesAmount in each department.
df.groupby('Department')['SalesAmount'].min()
# Out:
# Department
# Automobile      7695
# Clothing        5955
# Electronics    17263
# Groceries       5377
# Home Decor     17997
# Name: SalesAmount, dtype: int64

# %%
#25.	Find the employee with the highest total earnings.
df.head()
df.groupby('TotalEarnings')['EmployeeID'].max()
# Out:
# TotalEarnings
# 5538.31     1015
# 6312.30     1013
# 7801.13     1029
# 8464.50     1007
# 9654.12     1022
# 12590.69    1044
# 13914.94    1019
# 17780.89    1004
# 18896.85    1049
# 19245.02    1025
# 19516.64    1010
# 20476.80    1048
# 21699.26    1036
# 23470.97    1026
# 26887.12    1006
# 27490.89    1037
# 27982.01    1040
# 28090.71    1011
# 28174.30    1038
# 28734.30    1021
# 28934.85    1050
# 29276.00    1020
# 29454.22    1030
# 30058.38    1033
# 31506.45    1042
# 31866.45    1018
# 32727.25    1014
# 33338.70    1046
# 34128.82    1012
# 35272.65    1028
# 35743.06    1032
# 35806.50    1002
# 35910.00    1001
# 37788.64    1024
# 37852.60    1039
# 38924.08    1005
# 40379.05    1047
# 40873.60    1027
# 40908.51    1035
# 41263.08    1045
# 41428.26    1031
# 42745.56    1017
# 44132.34    1003
# 45483.52    1023
# 46332.49    1041
# 49120.70    1008
# 50282.64    1043
# 52057.66    1034
# 52552.68    1009
# 52860.60    1016
# Name: EmployeeID, dtype: int64

# %%
#26.	Count the number of employees who achieved and did not achieve their target.
df.head()
df.groupby('TargetAchieved')['EmployeeID'].count()
# Out:
# TargetAchieved
# No     24
# Yes    26
# Name: EmployeeID, dtype: int64

# %%
#27.	Find the average commission percentage per department.
df.groupby('Department')['CommissionPercentage'].mean()
# Out:
# Department
# Automobile     5.818182
# Clothing       5.909091
# Electronics    5.900000
# Groceries      5.400000
# Home Decor     6.375000
# Name: CommissionPercentage, dtype: float64

# %%
#28.	Find the highest TotalEarnings per region.
df.head()
df.groupby('Region')['TotalEarnings'].max()
# Out:
# Region
# East     52860.60
# North    40908.51
# South    49120.70
# West     50282.64
# Name: TotalEarnings, dtype: float64

# %%
#29.	Find the lowest TotalEarnings per department.
df.groupby('Region')['TotalEarnings'].min()
# Out:
# Region
# East      9654.12
# North    13914.94
# South     5538.31
# West      6312.30
# Name: TotalEarnings, dtype: float64

# %%
#30.	Count the number of employees per department
df.groupby('Department')['EmployeeID'].count()
# Out:
# Department
# Automobile     11
# Clothing       11
# Electronics    10
# Groceries      10
# Home Decor      8
# Name: EmployeeID, dtype: int64

# %%
#Data Transformation
#31.	Remove the EmployeeID column from the DataFrame.
df.drop(columns=['EmployeeID'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1120/596478241.py in <cell line: 0>()
#       1 #Data Transformation
#       2 #31.    Remove the EmployeeID column from the DataFrame.
# ----> 3 df.drop('EmployeeID',axis=1)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
# ...

# %%
#32.	Reset the index of the DataFrame.
df.reset_index(drop=True,inplace=True)

# %%
#33.	Replace all employees who did not achieve the target with "Needs Improvement" in the TargetAchieved column.
df['TargetAchieved'].replace('No','Needs Improvement',inplace=True)
# Out:
# /tmp/ipykernel_1120/2137185450.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TargetAchieved'].replace('No','Needs Improvement',inplace=True)

# %%
#34.	Create a new column PerformanceLevel with values: "High" if SalesAmount > 40000, "Medium" if between 20000-40000, else "Low".
df['PerformanceLevel'] = df['SalesAmount'].apply(lambda i: 'High' if i > 40000 else ('Medium' if i > 20000 else 'Low'))

# %%
#35.	Convert Age column to an integer type.
df['Age']=df['Age'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  50 non-null     object
#  1   Age                   50 non-null     int64
#  2   Department            50 non-null     category
#  3   Region                50 non-null     object
#  4   SalesAmount           50 non-null     int64
#  5   Target                50 non-null     int64
#  6   TargetAchieved        50 non-null     object
#  7   CommissionPercentage  50 non-null     int64
#  8   TotalEarnings         50 non-null     float64
#  9   PerformanceLevel      50 non-null     object
#  10  AboveAverageEarnings  50 non-null     object
# dtypes: category(1), float64(1), int64(4), object(5)
# memory usage: 4.3+ KB

# %%
#36.	Create a new column AboveAverageEarnings, which is "Yes" if TotalEarnings is above the average.
avg_earning= df['TotalEarnings'].mean()
df['AboveAverageEarnings']=df['TotalEarnings'].apply(lambda x: 'Yes' if x > avg_earning else 'No')

# %%
df.head()
# Out:
#          Name  Age   Department Region  SalesAmount  Target  \
# 0  Employee_1   28  Electronics  North        34200   17968
# 1  Employee_2   26   Home Decor   East        32850   42821
# 2  Employee_3   22   Home Decor  South        43267   40728
# 3  Employee_4   31  Electronics   West        17263   40183
# 4  Employee_5   49    Groceries   East        37427   17010
#
#       TargetAchieved  CommissionPercentage  TotalEarnings PerformanceLevel  \
# 0                Yes                     5       35910.00           Medium
# 1  Needs Improvement                     9       35806.50           Medium
# 2                Yes                     2       44132.34             High
# 3  Needs Improvement                     3       17780.89              Low
# 4                Yes                     4       38924.08           Medium
#
#   AboveAverageEarnings
# 0                  Yes
# 1                  Yes
# 2                  Yes
# 3                   No
# 4                  Yes

# %%
#37.	Convert the Department column to a categorical data type.
df['Department'] = df['Department'].astype('category')

# %%
#38.	Find the top 5 employees based on total earnings.
df.sort_values(by='TotalEarnings',ascending=False).head(5)
# Out:
#            Name  Age   Department Region  SalesAmount  Target  \
# 15  Employee_16   22  Electronics   East        48945   44965
# 8    Employee_9   31   Home Decor   East        49578   22738
# 33  Employee_34   42  Electronics   East        49111   31797
# 42  Employee_43   33   Home Decor   West        46558   15582
# 7    Employee_8   37    Groceries  South        47690   49267
#
#        TargetAchieved  CommissionPercentage  TotalEarnings PerformanceLevel  \
# 15                Yes                     8       52860.60             High
# 8                 Yes                     6       52552.68             High
# 33                Yes                     6       52057.66             High
# 42                Yes                     8       50282.64             High
# 7   Needs Improvement                     3       49120.70             High
#
#    AboveAverageEarnings
# 15                  Yes
# 8                   Yes
# 33                  Yes
# 42                  Yes
# ...

# %%
#39.	Find the bottom 5 employees based on total earnings.
df.sort_values(by='TotalEarnings',ascending=False).tail(5)
# Out:
#            Name  Age  Department Region  SalesAmount  Target  \
# 21  Employee_22   32   Groceries   East         8939   31223
# 6    Employee_7   43  Automobile   West         7695   32586
# 28  Employee_29   44    Clothing   West         7157   10232
# 12  Employee_13   41    Clothing   West         5955   28323
# 14  Employee_15   47   Groceries  South         5377   16274
#
#        TargetAchieved  CommissionPercentage  TotalEarnings PerformanceLevel  \
# 21  Needs Improvement                     8        9654.12              Low
# 6   Needs Improvement                    10        8464.50              Low
# 28  Needs Improvement                     9        7801.13              Low
# 12  Needs Improvement                     6        6312.30              Low
# 14  Needs Improvement                     3        5538.31              Low
#
#    AboveAverageEarnings
# 21                   No
# 6                    No
# 28                   No
# 12                   No
# ...

# %%
#40.	Save the modified DataFrame to a new CSV file.
df.to_csv('modified_sales_data.csv',index=False)

# %% [markdown]
# ## ***Questions on Cars Data for Pandas:***

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Data Sets/cars_data (1).csv")
df1
# Out:
#     CarID     Brand       Model  Year  Price  FuelType  Mileage  Horsepower  \
# 0       1       BMW    5 Series  2022  79402    Diesel    44.91         339
# 1       2  Mercedes     E-Class  2011  24117    Petrol    15.87         274
# 2       3  Mercedes         GLC  2014  40886  Electric    41.57         138
# 3       4     Honda        CR-V  2015  34459    Diesel    42.46         119
# 4       5  Mercedes     C-Class  2020  59752    Petrol    21.18         133
# 5       6      Ford    Explorer  2011  77712    Diesel    41.56         405
# 6       7     Honda       Pilot  2013  10300    Diesel    17.70         275
# 7       8    Toyota       Prius  2012  17388    Petrol    45.71         378
# 8       9  Mercedes         GLE  2013  25585  Electric    24.16         326
# 9      10      Ford    Explorer  2012  37985    Diesel    37.34         239
# 10     11      Ford      Fiesta  2019  67254    Petrol    15.29         134
# ...

# %%
# 1.	Display the first 5 rows of the dataset.
df1.head(5)
# Out:
#    CarID     Brand     Model  Year  Price  FuelType  Mileage  Horsepower  \
# 0      1       BMW  5 Series  2022  79402    Diesel    44.91         339
# 1      2  Mercedes   E-Class  2011  24117    Petrol    15.87         274
# 2      3  Mercedes       GLC  2014  40886  Electric    41.57         138
# 3      4     Honda      CR-V  2015  34459    Diesel    42.46         119
# 4      5  Mercedes   C-Class  2020  59752    Petrol    21.18         133
#
#    Torque  Seats Transmission Sold Region  SafetyRating  ResaleValue
# 0     493      2       Manual  Yes   East             1        68941
# 1     289      7    Automatic  Yes   West             4        19006
# 2     315      2    Automatic  Yes   East             2        30970
# 3     289      4    Automatic  Yes   West             1        23880
# 4     175      4       Manual  Yes  North             5        48077

# %%
# 2.	Show the last 5 rows of the dataset.
df1.tail(5)
# Out:
#     CarID   Brand       Model  Year  Price  FuelType  Mileage  Horsepower  \
# 45     46    Ford    Explorer  2016  17051  Electric    38.91         558
# 46     47   Honda      Accord  2015  49903    Diesel    37.78         243
# 47     48  Toyota  Highlander  2016  25138    Petrol    49.10         280
# 48     49  Toyota       Camry  2014  39294    Petrol    36.95         506
# 49     50     BMW    5 Series  2014  28773    Diesel    44.83         248
#
#     Torque  Seats Transmission Sold Region  SafetyRating  ResaleValue
# 45     193      5       Manual   No   West             1        11446
# 46     472      5    Automatic   No  North             5        33468
# 47     202      4    Automatic   No   West             2        22109
# 48     362      5       Manual  Yes  North             1        20293
# 49     252      2       Manual  Yes  South             1        25545

# %%
# 3.	Get the shape (number of rows and columns) of the dataset.
df1.shape
# Out:
# (50, 15)

# %%
# 4.	Display summary statistics for all numerical columns.
df1.describe()
# Out:
#           CarID         Year         Price    Mileage  Horsepower      Torque  \
# count  50.00000    50.000000     50.000000  50.000000   50.000000   50.000000
# mean   25.50000  2015.880000  45147.320000  32.278200  324.760000  361.700000
# std    14.57738     3.847289  19667.845968  11.848107  151.517974  139.352914
# min     1.00000  2010.000000  10300.000000  10.610000  107.000000  150.000000
# 25%    13.25000  2013.000000  28991.000000  21.915000  213.500000  257.750000
# 50%    25.50000  2015.000000  39489.500000  35.605000  277.500000  336.500000
# 75%    37.75000  2019.750000  63140.750000  42.237500  488.500000  478.250000
# max    50.00000  2023.000000  79402.000000  49.650000  579.000000  688.000000
#
#            Seats  SafetyRating   ResaleValue
# count  50.000000     50.000000     50.000000
# mean    4.220000      2.720000  33150.600000
# std     1.729575      1.512398  16788.502376
# min     2.000000      1.000000   7139.000000
# ...

# %%
# 5.	Get the column names of the dataset.
df1.columns
# Out:
# Index(['CarID', 'Brand', 'Model', 'Year', 'Price', 'FuelType', 'Mileage',
#        'Horsepower', 'Torque', 'Seats', 'Transmission', 'Sold', 'Region',
#        'SafetyRating', 'ResaleValue'],
#       dtype='object')

# %%
# 6.	Check for missing values in the dataset.
df1.isnull().sum()
# Out:
# CarID           0
# Brand           0
# Model           0
# Year            0
# Price           0
# FuelType        0
# Mileage         0
# Horsepower      0
# Torque          0
# Seats           0
# Transmission    0
# Sold            0
# Region          0
# SafetyRating    0
# ResaleValue     0
# dtype: int64

# %%
# 7.	Get the data types of each column Filtering and Sorting Questions
df1.dtypes
# Out:
# CarID             int64
# Brand            object
# Model            object
# Year              int64
# Price             int64
# FuelType         object
# Mileage         float64
# Horsepower        int64
# Torque            int64
# Seats             int64
# Transmission     object
# Sold             object
# Region           object
# SafetyRating      int64
# ResaleValue       int64
# dtype: object

# %%
# 8.	Sort the dataset by Price in descending order.
df1[['Price']].sort_values(by='Price',ascending=False)
# Out:
#     Price
# 0   79402
# 5   77712
# 34  77675
# 40  76039
# 33  75933
# 16  71536
# 44  69705
# 39  68178
# 10  67254
# 21  66352
# 37  64805
# 11  64608
# 17  63321
# 24  62600
# 27  62300
# 43  60310
# 4   59752
# 32  56907
# 35  54825
# 18  50248
# 46  49903
# 20  46256
# 15  43068
# 2   40886
# 42  39685
# 48  39294
# 30  38883
# 9   37985
# 19  37778
# 29  36720
# 22  35241
# 14  34824
# 3   34459
# 28  30749
# 13  30202
# 36  29725
# 12  29315
# 23  28883
# 49  28773
# 26  27977
# 31  25800
# 8   25585
# 47  25138
# 25  24263
# 1   24117
# 38  20997
# 7   17388
# 45  17051
# 41  16659
# 6   10300

# %%
# 9.	Select only the Brand, Model, and Price columns.
df1[['Brand','Model','Price']]
# Out:
#        Brand       Model  Price
# 0        BMW    5 Series  79402
# 1   Mercedes     E-Class  24117
# 2   Mercedes         GLC  40886
# 3      Honda        CR-V  34459
# 4   Mercedes     C-Class  59752
# 5       Ford    Explorer  77712
# 6      Honda       Pilot  10300
# 7     Toyota       Prius  17388
# 8   Mercedes         GLE  25585
# 9       Ford    Explorer  37985
# 10      Ford      Fiesta  67254
# 11     Honda       Civic  64608
# 12  Mercedes     E-Class  29315
# 13     Honda        CR-V  30202
# 14     Honda       Civic  34824
# 15      Ford       Focus  43068
# 16    Toyota  Highlander  71536
# 17      Ford      Fiesta  63321
# 18  Mercedes         GLC  50248
# 19     Honda       Civic  37778
# 20     Honda        CR-V  46256
# 21  Mercedes         GLC  66352
# 22  Mercedes     C-Class  35241
# 23    Toyota       Camry  28883
# 24      Ford     Mustang  62600
# 25       BMW          X3  24263
# 26  Mercedes     S-Class  27977
# 27    Toyota     Corolla  62300
# ...

# %%
#Filtering and Sorting Questions
#10.	Find all cars that have been sold.
df1['Sold'] == 'Yes'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12     True
# 13    False
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# 21     True
# 22     True
# 23     True
# 24    False
# 25     True
# 26     True
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33     True
# 34    False
# 35    False
# 36     True
# 37    False
# 38     True
# 39    False
# 40    False
# 41    False
# 42     True
# 43     True
# 44     True
# 45    False
# 46    False
# 47    False
# 48     True
# 49     True
# Name: Sold, dtype: bool

# %%
#11.	Find all cars that belong to the "BMW" brand.
df1['Brand'] == 'BMW'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35     True
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43     True
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49     True
# Name: Brand, dtype: bool

# %%
#12.	Find all cars that are from the year 2020 or later.
df1['Year'] >= 2020
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13     True
# 14    False
# 15    False
# 16     True
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22     True
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30    False
# 31    False
# 32    False
# 33     True
# 34     True
# 35    False
# 36    False
# 37    False
# 38    False
# 39     True
# 40    False
# 41     True
# 42    False
# 43     True
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: Year, dtype: bool

# %%
#13.	Find all cars that belong to the "North" region and have been sold.
df1.head()
df1[(df1['Region'] == 'North') & (df1['Sold'] == 'Yes')]
# Out:
#     CarID     Brand    Model  Year  Price FuelType  Mileage  Horsepower  \
# 4       5  Mercedes  C-Class  2020  59752   Petrol    21.18         133
# 43     44       BMW       X5  2023  60310   Petrol    14.98         215
# 48     49    Toyota    Camry  2014  39294   Petrol    36.95         506
#
#     Torque  Seats Transmission Sold Region  SafetyRating  ResaleValue
# 4      175      4       Manual  Yes  North             5        48077
# 43     375      2    Automatic  Yes  North             3        53420
# 48     362      5       Manual  Yes  North             1        20293

# %%
#14.	Filter cars that have Price greater than $40,000.
df1['Price'] > 40000
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# 13    False
# 14    False
# 15     True
# 16     True
# 17     True
# 18     True
# 19    False
# 20     True
# 21     True
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33     True
# 34     True
# 35     True
# 36    False
# 37     True
# 38    False
# 39     True
# 40     True
# 41    False
# 42    False
# 43     True
# 44     True
# 45    False
# 46     True
# 47    False
# 48    False
# 49    False
# Name: Price, dtype: bool

# %%
#15.	Find all cars with Horsepower greater than 300.
df1['Horsepower'] > 300
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7      True
# 8      True
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15    False
# 16     True
# 17     True
# 18    False
# 19     True
# 20    False
# 21    False
# 22     True
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30     True
# 31     True
# 32     True
# 33    False
# 34    False
# 35     True
# 36    False
# 37    False
# 38    False
# 39    False
# 40     True
# 41     True
# 42    False
# 43    False
# 44     True
# 45     True
# 46    False
# 47    False
# 48     True
# 49    False
# Name: Horsepower, dtype: bool

# %%
#16.	Find all cars with a Mileage greater than 30 MPG.
df1['Mileage'] > 30
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13     True
# 14     True
# 15    False
# 16     True
# 17    False
# 18     True
# 19    False
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25    False
# 26     True
# 27     True
# 28    False
# 29     True
# 30     True
# 31     True
# 32     True
# 33    False
# 34     True
# 35    False
# 36     True
# 37     True
# 38     True
# 39    False
# 40    False
# 41    False
# 42     True
# 43    False
# 44    False
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# Name: Mileage, dtype: bool

# %%
#17.	Find all cars that have an automatic transmission.
df1['Transmission'] == 'Automatic'
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24     True
# 25     True
# 26     True
# 27    False
# 28    False
# 29     True
# 30    False
# 31     True
# 32    False
# 33    False
# 34     True
# 35     True
# 36     True
# 37     True
# 38    False
# 39    False
# 40    False
# 41    False
# 42     True
# 43     True
# 44     True
# 45    False
# 46     True
# 47     True
# 48    False
# 49    False
# Name: Transmission, dtype: bool

# %%
#18.	Find all cars that have a SafetyRating of 5.
df1['SafetyRating'] == 5
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23     True
# 24    False
# 25     True
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33     True
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41     True
# 42    False
# 43    False
# 44     True
# 45    False
# 46     True
# 47    False
# 48    False
# 49    False
# Name: SafetyRating, dtype: bool

# %%
#Grouping and Aggregation Questions
#19.	Find the average Price of cars per brand.
df1.groupby('Brand')['Price'].mean()
# Out:
# Brand
# BMW         46216.333333
# Ford        50089.181818
# Honda       42085.181818
# Mercedes    44242.583333
# Toyota      43523.900000
# Name: Price, dtype: float64

# %%
#20.	Count the number of cars in each FuelType category.
df1.groupby('FuelType')['CarID'].count()
# Out:
# FuelType
# Diesel      17
# Electric    12
# Petrol      21
# Name: CarID, dtype: int64

# %%
#21.	Find the highest Price in each Brand.
df1.groupby('Brand')['Price'].max()
# Out:
# Brand
# BMW         79402
# Ford        77712
# Honda       76039
# Mercedes    75933
# Toyota      71536
# Name: Price, dtype: int64

# %%
#22.	Find the lowest Price in each Brand.
df1.groupby('Brand')['Price'].min()
# Out:
# Brand
# BMW         24263
# Ford        16659
# Honda       10300
# Mercedes    24117
# Toyota      17388
# Name: Price, dtype: int64

# %%
#23.	Find the car with the highest ResaleValue.
df1.groupby('ResaleValue')['CarID'].max()
# Out:
# ResaleValue
# 7139      7
# 10033     8
# 11446    46
# 14128    42
# 14372    39
# 14665    13
# 15836    26
# 16262    14
# 17662    27
# 18884     9
# 18886    32
# 18958    37
# 19006     2
# 19501    29
# 19527    24
# 20293    49
# 21668    15
# 22109    48
# 22622    23
# 23880     4
# 24917    30
# 25545    50
# 27197    43
# 27690    16
# 27816    19
# 30970     3
# 31463    31
# 32004    21
# 32158    20
# 32984    10
# 33468    47
# 37752    28
# 40083    38
# 40647    36
# 43926    40
# 45733    25
# 45789    12
# 46879    18
# 48077     5
# 49844    33
# 50319    17
# 50597    45
# 52467    22
# 52939    11
# 53420    44
# 59039    41
# 63652    34
# 66231    35
# 68106     6
# 68941     1
# Name: CarID, dtype: int64

# %%
#24.	Count the number of cars sold and not sold.
df1.groupby('Sold')['CarID'].count()
# Out:
# Sold
# No     25
# Yes    25
# Name: CarID, dtype: int64

# %%
#25.	Find the average Horsepower per Brand.
df1.groupby('Brand')['Horsepower'].mean()
# Out:
# Brand
# BMW         302.666667
# Ford        379.636364
# Honda       376.363636
# Mercedes    289.333333
# Toyota      263.400000
# Name: Horsepower, dtype: float64

# %%
#26.	Find the highest ResaleValue per Region.
df1.groupby('Region')['Horsepower'].mean()
# Out:
# Region
# East     308.272727
# North    323.600000
# South    300.866667
# West     364.142857
# Name: Horsepower, dtype: float64

# %%
#27.	Find the lowest Mileage per Brand.
df1.groupby('Brand')['Mileage'].min()
# Out:
# Brand
# BMW         13.32
# Ford        14.78
# Honda       10.61
# Mercedes    12.74
# Toyota      25.01
# Name: Mileage, dtype: float64

# %%
#28.	Count the number of cars per Transmission type.
df1.groupby('Transmission')['CarID'].count()
# Out:
# Transmission
# Automatic    22
# Manual       28
# Name: CarID, dtype: int64

# %%
#Data Manipulation Questions
#29.	Remove the CarID column from the dataset.
df1.head()
df1.drop(columns=['CarID'],inplace=True)

# %%
#30.	Reset the index of the DataFrame.
df1.reset_index(drop=True)
# Out:
#        Brand       Model  Year  Price  FuelType  Mileage  Horsepower  Torque  \
# 0        BMW    5 Series  2022  79402    Diesel    44.91         339     493
# 1   Mercedes     E-Class  2011  24117    Petrol    15.87         274     289
# 2   Mercedes         GLC  2014  40886  Electric    41.57         138     315
# 3      Honda        CR-V  2015  34459    Diesel    42.46         119     289
# 4   Mercedes     C-Class  2020  59752    Petrol    21.18         133     175
# 5       Ford    Explorer  2011  77712    Diesel    41.56         405     341
# 6      Honda       Pilot  2013  10300    Diesel    17.70         275     332
# 7     Toyota       Prius  2012  17388    Petrol    45.71         378     156
# 8   Mercedes         GLE  2013  25585  Electric    24.16         326     309
# 9       Ford    Explorer  2012  37985    Diesel    37.34         239     473
# 10      Ford      Fiesta  2019  67254    Petrol    15.29         134     480
# ...

# %%
#31.	Replace all unsold cars ("No") with "Available" in the Sold column.
df1['Sold'] = df1['Sold'].replace('No','Available')

# %%
#32.	Create a new column PerformanceCategory based on Horsepower (High: >300, Medium: 150-300, Low: <150).
df1['PerformanceCategory']=df1['Horsepower'].apply(lambda i:'High' if i > 300 else ('Medium' if i > 150 else 'Low'))

# %%
#33.	Convert the Year column to an integer type.
df1['Year'] = df1['Year'].astype('int')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CarID                50 non-null     int64
#  1   Brand                50 non-null     object
#  2   Model                50 non-null     object
#  3   Year                 50 non-null     int64
#  4   Price                50 non-null     int64
#  5   FuelType             50 non-null     category
#  6   Mileage              50 non-null     float64
#  7   Horsepower           50 non-null     int64
#  8   Torque               50 non-null     int64
#  9   Seats                50 non-null     int64
#  10  Transmission         50 non-null     object
#  11  Sold                 50 non-null     object
#  12  Region               50 non-null     object
#  13  SafetyRating         50 non-null     int64
#  14  ResaleValue          50 non-null     int64
# ...

# %%
#34.	Create a new column AboveAveragePrice, which is "Yes" if Price is above the average.
avg_price = df1['Price'].mean()
df1['AboveAveragePrice'] = df1['Price'].apply(lambda i:'Yes' if i > avg_price else 'No')

# %%
#35.	Convert the FuelType column to a categorical type.
df1['FuelType'] = df1['FuelType'].astype('category')

# %%
#36.	Find the top 5 most expensive cars.
df1['Price'].sort_values(ascending=False).head(5)
# Out:
# 0     79402
# 5     77712
# 34    77675
# 40    76039
# 33    75933
# Name: Price, dtype: int64

# %%
#37.	Find the bottom 5 cheapest cars.
df1['Price'].sort_values(ascending=False).head(5)
# Out:
# 0     79402
# 5     77712
# 34    77675
# 40    76039
# 33    75933
# Name: Price, dtype: int64

# %%
df1.head(7)
# Out:
#    CarID     Brand     Model  Year  Price  FuelType  Mileage  Horsepower  \
# 0      1       BMW  5 Series  2022  79402    Diesel    44.91         339
# 1      2  Mercedes   E-Class  2011  24117    Petrol    15.87         274
# 2      3  Mercedes       GLC  2014  40886  Electric    41.57         138
# 3      4     Honda      CR-V  2015  34459    Diesel    42.46         119
# 4      5  Mercedes   C-Class  2020  59752    Petrol    21.18         133
# 5      6      Ford  Explorer  2011  77712    Diesel    41.56         405
# 6      7     Honda     Pilot  2013  10300    Diesel    17.70         275
#
#    Torque  Seats Transmission       Sold Region  SafetyRating  ResaleValue  \
# 0     493      2       Manual        Yes   East             1        68941
# 1     289      7    Automatic        Yes   West             4        19006
# 2     315      2    Automatic        Yes   East             2        30970
# 3     289      4    Automatic        Yes   West             1        23880
# ...

# %%
#38.	Save the modified DataFrame to a new CSV file.
df1.to_csv('Modified_Cars_Data')

# %%
#39.	Display the first few rows of the modified DataFrame.
df11 = pd.read_csv("/content/Modified_Cars_Data")
df11.head(5)
# Out:
#    Unnamed: 0  CarID     Brand     Model  Year  Price  FuelType  Mileage  \
# 0           0      1       BMW  5 Series  2022  79402    Diesel    44.91
# 1           1      2  Mercedes   E-Class  2011  24117    Petrol    15.87
# 2           2      3  Mercedes       GLC  2014  40886  Electric    41.57
# 3           3      4     Honda      CR-V  2015  34459    Diesel    42.46
# 4           4      5  Mercedes   C-Class  2020  59752    Petrol    21.18
#
#    Horsepower  Torque  Seats Transmission Sold Region  SafetyRating  \
# 0         339     493      2       Manual  Yes   East             1
# 1         274     289      7    Automatic  Yes   West             4
# 2         138     315      2    Automatic  Yes   East             2
# 3         119     289      4    Automatic  Yes   West             1
# 4         133     175      4       Manual  Yes  North             5
#
#    ResaleValue
# 0        68941
# 1        19006
# 2        30970
# 3        23880
# 4        48077

# %%
#40.	Count the number of unique car brands in the dataset.
df11['Brand'].count()
# Out:
# np.int64(50)

# %% [markdown]
# ## ***Questions on Airline Dataset:***

# %%
# 1.	Load the CSV file into a Pandas DataFrame.
df2 = pd.read_csv("/content/drive/MyDrive/Data Sets/airline_passengers_indian.csv")
df2
# Out:
#     PassengerID FirstName    LastName  Age  Gender FlightNumber  Departure  \
# 0             1     Aarav      Sharma   25    Male        AI101     Mumbai
# 1             2    Vihaan       Verma   30    Male        BA202      Delhi
# 2             3    Vivaan       Patel   45    Male        DL303  Bangalore
# 3             4     Anaya       Desai   28  Female        EK404    Chennai
# 4             5      Myra        Iyer   34  Female        QR505    Kolkata
# 5             6     Aryan        Nair   22    Male        LH606  Hyderabad
# 6             7    Ishaan       Mehta   40    Male        AF707       Pune
# 7             8     Kabir         Rao   38    Male        SQ808  Ahmedabad
# 8             9    Saanvi       Joshi   29  Female        UA909    Lucknow
# 9            10    Aadhya        Bhat   27  Female        AI110     Jaipur
# 10           11    Advait      Kapoor   32    Male        BA211     Mumbai
# ...

# %%
#2.	Display the first 5 rows of the DataFrame.
df2.head(5)
# Out:
#    PassengerID FirstName LastName  Age  Gender FlightNumber  Departure  \
# 0            1     Aarav   Sharma   25    Male        AI101     Mumbai
# 1            2    Vihaan    Verma   30    Male        BA202      Delhi
# 2            3    Vivaan    Patel   45    Male        DL303  Bangalore
# 3            4     Anaya    Desai   28  Female        EK404    Chennai
# 4            5      Myra     Iyer   34  Female        QR505    Kolkata
#
#    Destination  TicketPrice SeatClass     Status
# 0       London          500   Economy  Confirmed
# 1     New York          750  Business  Cancelled
# 2  Los Angeles          600   Economy  Confirmed
# 3        Dubai         1200     First  Confirmed
# 4        Tokyo          900  Business    On Hold

# %%
#3.	Display the last 5 rows of the DataFrame.
df2.tail(5)
# Out:
#     PassengerID FirstName    LastName  Age  Gender FlightNumber  Departure  \
# 15           16      Riya        Bose   23  Female        AF722  Hyderabad
# 16           17   Krishna         Das   36    Male        SQ833       Pune
# 17           18   Shaurya      Saxena   41    Male        UA944  Ahmedabad
# 18           19     Tanvi  Chatterjee   48  Female        AI123    Lucknow
# 19           20     Arjun       Gupta   33    Male        QR567     Jaipur
#
#       Destination  TicketPrice SeatClass     Status
# 15         Munich          970     First  Confirmed
# 16           Rome         1150  Business    On Hold
# 17      Hong Kong          730   Economy  Confirmed
# 18  San Francisco          670   Economy  Confirmed
# 19      Singapore          910  Business    On Hold

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#4.	Get the total number of rows and columns in the DataFrame.
df2.shape
# Out:
# (20, 11)

# %%
#5.	Display all column names in the dataset.
df2.columns
# Out:
# Index(['PassengerID', 'FirstName', 'LastName', 'Age', 'Gender', 'FlightNumber',
#        'Departure', 'Destination', 'TicketPrice', 'SeatClass', 'Status'],
#       dtype='object')

# %%
#6.	Get summary statistics of numerical columns.
df2.describe()
# Out:
#        PassengerID        Age  TicketPrice
# count     20.00000  20.000000    20.000000
# mean      10.50000  33.650000   846.000000
# std        5.91608   8.034629   218.352684
# min        1.00000  22.000000   500.000000
# 25%        5.75000  27.750000   692.500000
# 50%       10.50000  32.500000   825.000000
# 75%       15.25000  38.500000   955.000000
# max       20.00000  50.000000  1300.000000

# %%
#7.	Check for missing values in the dataset Data Selection
df2.isnull().sum()
# Out:
# PassengerID     0
# FirstName       0
# LastName        0
# Age             0
# Gender          0
# FlightNumber    0
# Departure       0
# Destination     0
# TicketPrice     0
# SeatClass       0
# Status          0
# dtype: int64

# %%
#8.	Select only the 'FirstName' and 'LastName' columns.
df2[['FirstName','LastName']]
# Out:
#    FirstName    LastName
# 0      Aarav      Sharma
# 1     Vihaan       Verma
# 2     Vivaan       Patel
# 3      Anaya       Desai
# 4       Myra        Iyer
# 5      Aryan        Nair
# 6     Ishaan       Mehta
# 7      Kabir         Rao
# 8     Saanvi       Joshi
# 9     Aadhya        Bhat
# 10    Advait      Kapoor
# 11     Rudra      Chopra
# 12      Pari    Malhotra
# 13     Kiaan        Jain
# 14    Tanish     Agarwal
# 15      Riya        Bose
# 16   Krishna         Das
# 17   Shaurya      Saxena
# 18     Tanvi  Chatterjee
# 19     Arjun       Gupta

# %%
#9.	Retrieve the ticket price of the 10th passenger.
df2.iloc[9]['TicketPrice']
# Out:
# np.int64(650)

# %%
#Filtering & Sorting
#10.	Find all passengers whose ticket price is greater than ₹900.
df2['TicketPrice'] > 900
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15     True
# 16     True
# 17    False
# 18    False
# 19     True
# Name: TicketPrice, dtype: bool

# %%
#11.	Count the number of passengers in each seat class.
df2.groupby('SeatClass')['SeatClass'].count()
# Out:
# SeatClass
# Business    7
# Economy     9
# First       4
# Name: SeatClass, dtype: int64

# %%
#12.	Find the passenger with the highest ticket price.
df2.head()
df2[df2['TicketPrice'] == df2['TicketPrice'].max()]
# Out:
#     PassengerID FirstName  LastName  Age  Gender FlightNumber  Departure  \
# 12           13      Pari  Malhotra   50  Female        EK433  Bangalore
#
#     Destination  TicketPrice SeatClass     Status
# 12  Los Angeles         1300     First  Confirmed

# %%
#13.	Get the average ticket price of all passengers.
df2['TicketPrice'].mean()
# Out:
# np.float64(846.0)

# %%
#14.	Sort the passengers by ticket price in descending order.
df2.sort_values(by='TicketPrice',ascending=False)
# Out:
#     PassengerID FirstName    LastName  Age  Gender FlightNumber  Departure  \
# 12           13      Pari    Malhotra   50  Female        EK433  Bangalore
# 3             4     Anaya       Desai   28  Female        EK404    Chennai
# 16           17   Krishna         Das   36    Male        SQ833       Pune
# 7             8     Kabir         Rao   38    Male        SQ808  Ahmedabad
# 15           16      Riya        Bose   23  Female        AF722  Hyderabad
# 6             7    Ishaan       Mehta   40    Male        AF707       Pune
# 19           20     Arjun       Gupta   33    Male        QR567     Jaipur
# 4             5      Myra        Iyer   34  Female        QR505    Kolkata
# 13           14     Kiaan        Jain   31    Male        QR544    Chennai
# 5             6     Aryan        Nair   22    Male        LH606  Hyderabad
# 14           15    Tanish     Agarwal   35    Male        LH633    Kolkata
# ...

# %%
#15.	List all passengers who booked a 'First' class ticket.
df2['SeatClass'] == 'First'
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# Name: SeatClass, dtype: bool

# %%
#Aggregations & Grouping
#20.	Find the average ticket price per seat class.
df2.groupby('SeatClass')['TicketPrice'].mean()
# Out:
# SeatClass
# Business     917.142857
# Economy      675.555556
# First       1105.000000
# Name: TicketPrice, dtype: float64

# %%
#21.	Count the number of passengers in each 'AgeGroup'.
df2.groupby('Age').size().sort_values(ascending=False)
# Out:
# Age
# 22    1
# 23    1
# 25    1
# 26    1
# 27    1
# 28    1
# 29    1
# 30    1
# 31    1
# 32    1
# 33    1
# 34    1
# 35    1
# 36    1
# 38    1
# 40    1
# 41    1
# 45    1
# 48    1
# 50    1
# dtype: int64

# %%
#22.	Find the highest ticket price in each seat class.
df2.groupby('SeatClass')['TicketPrice'].max()
# Out:
# SeatClass
# Business    1150
# Economy      850
# First       1300
# Name: TicketPrice, dtype: int64

# %%
#23.	Find the lowest ticket price in each seat class.
df2.head()
df2.groupby('SeatClass')['TicketPrice'].max()
# Out:
# SeatClass
# Business    1150
# Economy      850
# First       1300
# Name: TicketPrice, dtype: int64

# %%
#24.	Find the passenger with the highest age.
df2.head()
df2.groupby('PassengerID')['Age'].max()
# Out:
# PassengerID
# 1     25
# 2     30
# 3     45
# 4     28
# 5     34
# 6     22
# 7     40
# 8     38
# 9     29
# 10    27
# 11    32
# 12    26
# 13    50
# 14    31
# 15    35
# 16    23
# 17    36
# 18    41
# 19    48
# 20    33
# Name: Age, dtype: int64

# %%
(df2['Status'] == 'Confirmed').count()
# Out:
# np.int64(20)

# %%
df2.head()
# Out:
#    PassengerID FirstName LastName  Age  Gender FlightNumber  Departure  \
# 0            1     Aarav   Sharma   25    Male        AI101     Mumbai
# 1            2    Vihaan    Verma   30    Male        BA202      Delhi
# 2            3    Vivaan    Patel   45    Male        DL303  Bangalore
# 3            4     Anaya    Desai   28  Female        EK404    Chennai
# 4            5      Myra     Iyer   34  Female        QR505    Kolkata
#
#    Destination  TicketPrice SeatClass     Status
# 0       London          500   Economy  Confirmed
# 1     New York          750  Business  Cancelled
# 2  Los Angeles          600   Economy  Confirmed
# 3        Dubai         1200     First  Confirmed
# 4        Tokyo          900  Business    On Hold

# %%
#26.	Find the average ticket price of passengers in Business Class.
df2.head()
(df2['SeatClass'] == 'Business').mean()
# Out:
# np.float64(0.35)

# %%
#27.	Find the highest ticket price for each flight.
df2.head()
df2.groupby('FlightNumber')['TicketPrice'].max()
# Out:
# FlightNumber
# AF707     950
# AF722     970
# AI101     500
# AI110     650
# AI123     670
# BA202     750
# BA211     720
# DL303     600
# DL322     580
# EK404    1200
# EK433    1300
# LH606     850
# LH633     800
# QR505     900
# QR544     890
# QR567     910
# SQ808    1100
# SQ833    1150
# UA909     700
# UA944     730
# Name: TicketPrice, dtype: int64

# %%
#Data Transformations
#28.	Remove the 'Gender' column from the dataset.
df2.drop(columns=['Gender'],inplace=True)

# %%
#29.	Reset the index of the dataset.
df2.reset_index(drop=True)
# Out:
#     PassengerID FirstName    LastName  Age FlightNumber  Departure  \
# 0             1     Aarav      Sharma   25        AI101     Mumbai
# 1             2    Vihaan       Verma   30        BA202      Delhi
# 2             3    Vivaan       Patel   45        DL303  Bangalore
# 3             4     Anaya       Desai   28        EK404    Chennai
# 4             5      Myra        Iyer   34        QR505    Kolkata
# 5             6     Aryan        Nair   22        LH606  Hyderabad
# 6             7    Ishaan       Mehta   40        AF707       Pune
# 7             8     Kabir         Rao   38        SQ808  Ahmedabad
# 8             9    Saanvi       Joshi   29        UA909    Lucknow
# 9            10    Aadhya        Bhat   27        AI110     Jaipur
# 10           11    Advait      Kapoor   32        BA211     Mumbai
# 11           12     Rudra      Chopra   26        DL322      Delhi
# 12           13      Pari    Malhotra   50        EK433  Bangalore
# ...

# %%
#30.	Replace all 'On Hold' statuses with 'Pending'.
df2['Status'].replace('On Hold','Pending')
# Out:
# 0     Confirmed
# 1     Cancelled
# 2     Confirmed
# 3     Confirmed
# 4       Pending
# 5     Confirmed
# 6     Cancelled
# 7     Confirmed
# 8       Pending
# 9     Confirmed
# 10    Confirmed
# 11    Cancelled
# 12    Confirmed
# 13      Pending
# 14    Confirmed
# 15    Confirmed
# 16      Pending
# 17    Confirmed
# 18    Confirmed
# 19      Pending
# Name: Status, dtype: object

# %%
#31.	Replace all ticket prices below ₹600 with 'Low Price'.
df2['TicketPrice'].replace(600,'Low Price')
# Out:
# 0           500
# 1           750
# 2     Low Price
# 3          1200
# 4           900
# 5           850
# 6           950
# 7          1100
# 8           700
# 9           650
# 10          720
# 11          580
# 12         1300
# 13          890
# 14          800
# 15          970
# 16         1150
# 17          730
# 18          670
# 19          910
# Name: TicketPrice, dtype: object

# %%
#32.	Convert the 'TicketPrice' column to an integer type.
df2['TicketPrice'].astype('int')
# Out:
# 0      500
# 1      750
# 2      600
# 3     1200
# 4      900
# 5      850
# 6      950
# 7     1100
# 8      700
# 9      650
# 10     720
# 11     580
# 12    1300
# 13     890
# 14     800
# 15     970
# 16    1150
# 17     730
# 18     670
# 19     910
# Name: TicketPrice, dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerID   20 non-null     int64
#  1   FirstName     20 non-null     object
#  2   LastName      20 non-null     object
#  3   Age           20 non-null     int64
#  4   FlightNumber  20 non-null     object
#  5   Departure     20 non-null     object
#  6   Destination   20 non-null     object
#  7   TicketPrice   20 non-null     int64
#  8   SeatClass     20 non-null     object
#  9   Status        20 non-null     object
# dtypes: int64(3), object(7)
# memory usage: 1.7+ KB

# %%
#33.	Create a new column 'AboveAverage' with 'Yes' if the ticket price is above the dataset's average.
Avg_Price=df2['TicketPrice'].mean()
df2['AboveAverage'] = df1['Price'].apply(lambda i: 'Yes' if i > Avg_Price else 'No')

# %%
#34.	Convert the 'SeatClass' column to a categorical data type.
df2['SeatClass'] = df2['SeatClass'].astype('category')

# %%
#Top & Bottom Records
#35.	Find the top 5 passengers with the highest ticket price.
df2.sort_values(by='TicketPrice',ascending=False).head(5)
# Out:
#     PassengerID FirstName  LastName  Age FlightNumber  Departure  Destination  \
# 12           13      Pari  Malhotra   50        EK433  Bangalore  Los Angeles
# 3             4     Anaya     Desai   28        EK404    Chennai        Dubai
# 16           17   Krishna       Das   36        SQ833       Pune         Rome
# 7             8     Kabir       Rao   38        SQ808  Ahmedabad    Hong Kong
# 15           16      Riya      Bose   23        AF722  Hyderabad       Munich
#
#     TicketPrice SeatClass     Status AboveAverage
# 12         1300     First  Confirmed          Yes
# 3          1200     First  Confirmed          Yes
# 16         1150  Business    Pending          Yes
# 7          1100  Business  Confirmed          Yes
# 15          970     First  Confirmed          Yes

# %%
#36.	Find the bottom 5 passengers with the lowest ticket price.
df2.sort_values(by='TicketPrice',ascending=False).tail(5)
# Out:
#     PassengerID FirstName    LastName  Age FlightNumber  Departure  \
# 18           19     Tanvi  Chatterjee   48        AI123    Lucknow
# 9            10    Aadhya        Bhat   27        AI110     Jaipur
# 2             3    Vivaan       Patel   45        DL303  Bangalore
# 11           12     Rudra      Chopra   26        DL322      Delhi
# 0             1     Aarav      Sharma   25        AI101     Mumbai
#
#       Destination  TicketPrice SeatClass     Status AboveAverage
# 18  San Francisco          670   Economy  Confirmed          Yes
# 9       Singapore          650   Economy  Confirmed          Yes
# 2     Los Angeles          600   Economy  Confirmed          Yes
# 11       New York          580   Economy  Cancelled          Yes
# 0          London          500   Economy  Confirmed          Yes

# %%
#Save Data
#37.	Save the modified DataFrame to a new CSV file.
df2.to_csv('Modified_Airline_Data')

# %%
df2.head(7)
# Out:
#    PassengerID FirstName LastName  Age FlightNumber  Departure  Destination  \
# 0            1     Aarav   Sharma   25        AI101     Mumbai       London
# 1            2    Vihaan    Verma   30        BA202      Delhi     New York
# 2            3    Vivaan    Patel   45        DL303  Bangalore  Los Angeles
# 3            4     Anaya    Desai   28        EK404    Chennai        Dubai
# 4            5      Myra     Iyer   34        QR505    Kolkata        Tokyo
# 5            6     Aryan     Nair   22        LH606  Hyderabad       Munich
# 6            7    Ishaan    Mehta   40        AF707       Pune         Rome
#
#    TicketPrice SeatClass     Status AboveAverage
# 0          500   Economy  Confirmed          Yes
# 1          750  Business  Cancelled          Yes
# 2          600   Economy  Confirmed          Yes
# 3         1200     First  Confirmed          Yes
# 4          900  Business    Pending          Yes
# 5          850   Economy  Confirmed          Yes
# ...

# %% [markdown]
# ## ***Questions on Hotel Database:***

# %%
import numpy as np
import pandas as pd

# %%
df3 = pd.read_csv("/content/drive/MyDrive/hotel_data.csv")
df3
# Out:
#     HotelID          HotelName       Location RoomType  Rating  PricePerNight  \
# 0         1       Mountain Inn          Miami      NaN     5.0          200.0
# 1         2  City Lights Hotel       New York   Double     3.0          100.0
# 2         3         Ocean View          Miami   Double     NaN          100.0
# 3         4  City Lights Hotel    Los Angeles    Suite     3.0          150.0
# 4         5  City Lights Hotel       New York    Suite     3.0            NaN
# ..      ...                ...            ...      ...     ...            ...
# 95       96         Ocean View        Chicago   Deluxe     4.0          200.0
# 96       97  City Lights Hotel        Chicago   Double     4.0           50.0
# 97       98         Royal Stay       New York   Double     5.0            NaN
# 98       99         Royal Stay  San Francisco   Double     5.0          250.0
# 99      100       Grand Palace          Miami   Double     5.0          150.0
#
#    BookingStatus CheckInDate
# ...

# %%
#Data Cleaning Questions
#1.	How do you fill missing values in the Rating column with the value avg(rating) or "Medium"?
avg_rating = df3['Rating'].mean()

df3['Rating'].fillna(avg_rating,inplace=True)
# Out:
# /tmp/ipykernel_972/1904023251.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df3['Rating'].fillna(avg_rating,inplace=True)

# %%
#2.	Replace missing values in the CustomerName column with "Guest".
df3['CustomerName'].fillna('Guest',inplace=True)
#Shgowing Error Because there is no any column Named "CustomerName"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CustomerName'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_972/2354145336.py in <cell line: 0>()
# ...

# %%
#3.	Identify and remove any duplicate records from the dataset.
df3.drop_duplicates(inplace=True)

# %%
#4.	Convert the CheckInDate column to a proper datetime format.
df3['CheckInDate']=pd.to_datetime(df3['CheckInDate'])

# %%
#5.	Extract the year from the CheckInDate column.
df3['CheckInYear']=df3['CheckInDate'].dt.year

# %%
#6.	Extract the month from the CheckInDate column.
df3['CheckinMonth']=df3['CheckInDate'].dt.month

# %%
#7.	Extract the day of the week from the CheckInDate column.
df3['CheckinDay']=df3['CheckInDate'].dt.day

# %%
#8.	Find all records where the RoomsAvailable column has values greater than 150.
df3(df3['RoomAvailale'] > 150)
#There is no any column named "RoomsAvailable"

# %%
#9.	Find the hotels that have a price per night greater than 400.
df3['PricePerNight'] > 400
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Name: PricePerNight, Length: 100, dtype: bool

# %%
#10.Remove hotels that have null values in the Location column.
df3.dropna(subset = ['RoomType'],inplace=True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 93 entries, 1 to 99
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HotelID        93 non-null     int64
#  1   HotelName      93 non-null     object
#  2   Location       93 non-null     object
#  3   RoomType       93 non-null     object
#  4   Rating         93 non-null     float64
#  5   PricePerNight  88 non-null     float64
#  6   BookingStatus  82 non-null     object
#  7   CheckInDate    93 non-null     datetime64[ns]
#  8   CheckInYear    93 non-null     int32
#  9   CheckinMonth   93 non-null     int32
#  10  CheckinDay     93 non-null     int32
# dtypes: datetime64[ns](1), float64(2), int32(3), int64(1), object(4)
# memory usage: 7.6+ KB

# %%
#Date-Based Questions
#11.	Find all hotels where the check-in date is in the year 2023.
df3['CheckInDate']=pd.to_datetime(df3['CheckInDate'])
df3[df3['CheckInDate'].dt.year == 2023]
# Out:
# Empty DataFrame
# Columns: [HotelID, HotelName, Location, RoomType, Rating, PricePerNight, BookingStatus, CheckInDate, CheckInYear, CheckinMonth, CheckinDay]
# Index: []

# %%
#12.	Find hotels where the check-in date falls on a weekend (Saturday or Sunday).
df3[df3['CheckInDate'].dt.dayofweek.isin([5,6])]
# Out:
#     HotelID          HotelName       Location RoomType    Rating  \
# 1         2  City Lights Hotel       New York   Double  3.000000
# 2         3         Ocean View          Miami   Double  4.010989
# 3         4  City Lights Hotel    Los Angeles    Suite  3.000000
# 4         5  City Lights Hotel       New York    Suite  3.000000
# 5         6         Royal Stay  San Francisco   Deluxe  4.000000
# ..      ...                ...            ...      ...       ...
# 95       96         Ocean View        Chicago   Deluxe  4.000000
# 96       97  City Lights Hotel        Chicago   Double  4.000000
# 97       98         Royal Stay       New York   Double  5.000000
# 98       99         Royal Stay  San Francisco   Double  5.000000
# 99      100       Grand Palace          Miami   Double  5.000000
#
#     PricePerNight BookingStatus         CheckInDate  CheckInYear  \
# 1           100.0     Confirmed 2026-06-20 03:16:48         2026
# ...

# %%
#13.	Find the total number of check-ins for each month.
df3.groupby(df3['CheckInDate'].dt.to_period('M')).size().reset_index(name='total_check_ins')
# Out:
#   CheckInDate  total_check_ins
# 0     2026-06               93

# %%
#14.	Find the number of hotels checked in per city.
df3.groupby('Location')['HotelName'].nunique().reset_index(name='unique_hotels_count')
# Out:
#         Location  unique_hotels_count
# 0        Chicago                    4
# 1    Los Angeles                    5
# 2          Miami                    5
# 3       New York                    4
# 4  San Francisco                    5

# %%
#15.	Count the total number of hotels checked in each year.
df3.groupby('CheckInYear')['HotelName'].count().reset_index(name='hotels_count')
# Out:
#    CheckInYear  hotels_count
# 0         2026            93

# %%
#16.	Find the highest price per night for each location.
df3.groupby('Location')['PricePerNight'].max().reset_index(name='highest_price_per_night')
# Out:
#         Location  highest_price_per_night
# 0        Chicago                    250.0
# 1    Los Angeles                    250.0
# 2          Miami                    250.0
# 3       New York                    250.0
# 4  San Francisco                    250.0

# %%
#17.	Find the hotel with the most available rooms.
df3.groupby('RoomType')['HotelName'].nunique().reset_index(name='unique_hotels_count')
# Out:
#   RoomType  unique_hotels_count
# 0   Deluxe                    5
# 1   Double                    5
# 2   Single                    5
# 3    Suite                    5

# %%
#18.	Find the average rating of hotels per city.
df3.groupby('Location')['Rating'].mean().reset_index(name='Average_Ratings_Per_City')
# Out:
#         Location  Average_Ratings_Per_City
# 0        Chicago                  4.056777
# 1    Los Angeles                  3.788069
# 2          Miami                  3.905808
# 3       New York                  4.042125
# 4  San Francisco                  4.250000

# %%
#19.	Find all hotels where the check-in date is in December.
df3[df3['CheckInDate'].dt.month == 12]
# Out:
# Empty DataFrame
# Columns: [HotelID, HotelName, Location, RoomType, Rating, PricePerNight, BookingStatus, CheckInDate, CheckInYear, CheckinMonth, CheckinDay]
# Index: []

# %%
#20.	Export the cleaned dataset into a new CSV file.
df3.to_csv('cleaned_hotel_data.csv',index=False)

# %%
df3.head(7)
# Out:
#    HotelID          HotelName       Location RoomType    Rating  \
# 0        1       Mountain Inn          Miami      NaN  5.000000
# 1        2  City Lights Hotel       New York   Double  3.000000
# 2        3         Ocean View          Miami   Double  4.010989
# 3        4  City Lights Hotel    Los Angeles    Suite  3.000000
# 4        5  City Lights Hotel       New York    Suite  3.000000
# 5        6         Royal Stay  San Francisco   Deluxe  4.000000
# 6        7         Ocean View        Chicago   Deluxe  4.010989
#
#    PricePerNight BookingStatus         CheckInDate  CheckInYear  CheckinMonth  \
# 0          200.0     Cancelled 2026-06-20 03:16:48         2026             6
# 1          100.0     Confirmed 2026-06-20 03:16:48         2026             6
# 2          100.0     Cancelled 2026-06-20 03:16:48         2026             6
# 3          150.0     Confirmed 2026-06-20 03:16:48         2026             6
# ...

# %% [markdown]
# ## ***Questions on Hospital Database:***

# %%
import numpy as np
import pandas as pd

# %%
# SECTION 1: BASIC DATA EXPLORATION (1–15)
#1.	Load the patient master CSV file into a Pandas DataFrame
# Note: Use pd.read_csv() and store it in a DataFrame variable. Make sure the file path is correct.
df1 = pd.read_csv("/content/drive/MyDrive/patient_master_1.csv")
df1
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 2         P00003       Neha     Joshi    Male   56    1969-12-29         AB-
# 3         P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 4         P00005      Rohan     Verma    Male   41    1984-02-11          A-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19995     P19996     Anjali     Mehta    Male   36    1989-10-07          A-
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
# 19997     P19998     Anjali     Singh  Female   46    1979-01-16          A-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
# ...

# %%
df2 = pd.read_csv("/content/drive/MyDrive/patient_master_2.csv")
df2
# Out:
#        Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0          P20001      Sneha      Iyer  Female   44    1981-08-24         AB-
# 1          P20002      Sneha    Sharma    Male   44    1981-11-02         AB-
# 2          P20003      Sneha     Joshi    Male   27    1998-08-12         AB+
# 3          P20004     Suresh     Mehta    Male   59    1966-11-19          O+
# 4          P20005       Amit  Kulkarni  Female   59    1966-01-15          B+
# ...           ...        ...       ...     ...  ...           ...         ...
# 139995    P159996      Arjun     Patil  Female   60    1965-04-21          B+
# 139996    P159997      Priya     Verma  Female   53    1972-07-09          B+
# 139997    P159998      Priya     Gupta    Male   59    1966-11-27          B+
# 139998    P159999       Neha     Mehta  Female   27    1998-08-14          A-
# 139999    P160000     Kavita    Sharma    Male   31    1994-09-09          A+
#
# ...

# %%
#2.	Display the first 5 rows of the dataset
# Note: This helps you quickly understand column names, data format, and sample values.
df1.head()
# Out:
#   Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0     P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1     P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 2     P00003       Neha     Joshi    Male   56    1969-12-29         AB-
# 3     P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 4     P00005      Rohan     Verma    Male   41    1984-02-11          A-
#
#   Marital_Status  Phone_Number           Email  ... Height_cm Weight_kg   BMI  \
# 0         Single    9698790602  user1@mail.com  ...       155        50  20.8
# 1        Married    9762620912  user2@mail.com  ...       168        74  26.2
# 2         Single    9522528550  user3@mail.com  ...       169        71  24.9
# 3        Married    9196136323  user4@mail.com  ...       162        60  22.9
# 4         Single    9644918514  user5@mail.com  ...       151        87  38.2
#
# ...

# %%
#3.	Display the last 5 rows of the dataset
# Note: Useful to verify the ending records and check data completeness.
df1.tail()
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 19995     P19996     Anjali     Mehta    Male   36    1989-10-07          A-
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
# 19997     P19998     Anjali     Singh  Female   46    1979-01-16          A-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
#       Marital_Status  Phone_Number               Email  ... Height_cm  \
# 19995         Single    9990287038  user19996@mail.com  ...       173
# 19996         Single    9498150434  user19997@mail.com  ...       174
# 19997        Married    9852974113  user19998@mail.com  ...       167
# 19998         Single    9925330649  user19999@mail.com  ...       157
# 19999         Single    9951983597  user20000@mail.com  ...       155
#
#       Weight_kg   BMI Smoking_Status  Alcohol_Consumption  Chronic_Condition  \
# ...

# %%
#4.	Find the total number of rows and columns
# Note: Output should be in the form (rows, columns).
df1.shape
# Out:
# (20000, 25)

# %%
# 5.	Display column names
# Note: Helps identify exact column names to avoid spelling mistakes later.
df1.columns
# Out:
# Index(['Patient_ID', 'First_Name', 'Last_Name', 'Gender', 'Age',
#        'Date_of_Birth', 'Blood_Group', 'Marital_Status', 'Phone_Number',
#        'Email', 'Address', 'City', 'State', 'Country', 'Pincode', 'Height_cm',
#        'Weight_kg', 'BMI', 'Smoking_Status', 'Alcohol_Consumption',
#        'Chronic_Condition', 'Primary_Doctor_ID', 'Insurance_Provider',
#        'Insurance_Policy_No', 'Registration_Date'],
#       dtype='object')

# %%
# 6.	Display data types of all columns
# Note: Verify whether numeric columns are stored as int/float and dates as object/datetime.
df1.dtypes
# Out:
# Patient_ID              object
# First_Name              object
# Last_Name               object
# Gender                  object
# Age                      int64
# Date_of_Birth           object
# Blood_Group             object
# Marital_Status          object
# Phone_Number             int64
# Email                   object
# Address                 object
# City                    object
# State                   object
# Country                 object
# Pincode                  int64
# Height_cm                int64
# Weight_kg                int64
# BMI                    float64
# Smoking_Status          object
# Alcohol_Consumption     object
# Chronic_Condition       object
# Primary_Doctor_ID       object
# Insurance_Provider      object
# Insurance_Policy_No     object
# Registration_Date       object
# dtype: object

# %%
# 7.	Show summary statistics for numerical columns
# Note: Includes count, mean, min, max, and standard deviation.
df1.describe()
# Out:
#                 Age  Phone_Number        Pincode     Height_cm     Weight_kg  \
# count  20000.000000  2.000000e+04   20000.000000  20000.000000  20000.000000
# mean      43.882750  9.499262e+09  405528.641150    165.002850     69.975750
# std        9.481455  2.885452e+08    3206.324183      8.910382     11.827669
# min       27.000000  9.000107e+09  400001.000000    150.000000     50.000000
# 25%       36.000000  9.251704e+09  402766.500000    157.000000     60.000000
# 50%       44.000000  9.497135e+09  405511.000000    165.000000     70.000000
# 75%       52.000000  9.750070e+09  408298.250000    173.000000     80.000000
# max       60.000000  9.999997e+09  411099.000000    180.000000     90.000000
#
#                 BMI
# count  20000.000000
# mean      25.927300
# std        5.233785
# min       15.400000
# 25%       21.800000
# 50%       25.600000
# 75%       29.500000
# max       40.000000

# %%
# 8.	Show summary statistics for all columns
# Note: Includes categorical stats like unique values and most frequent value.
df1.describe(include='all')
# Out:
#        Patient_ID First_Name Last_Name Gender           Age Date_of_Birth  \
# count       20000      20000     20000  20000  20000.000000         20000
# unique      20000         10        10      2           NaN          9778
# top        P19984      Pooja     Patil   Male           NaN    1975-06-07
# freq            1       2085      2067  10142           NaN             8
# mean          NaN        NaN       NaN    NaN     43.882750           NaN
# std           NaN        NaN       NaN    NaN      9.481455           NaN
# min           NaN        NaN       NaN    NaN     27.000000           NaN
# 25%           NaN        NaN       NaN    NaN     36.000000           NaN
# 50%           NaN        NaN       NaN    NaN     44.000000           NaN
# 75%           NaN        NaN       NaN    NaN     52.000000           NaN
# max           NaN        NaN       NaN    NaN     60.000000           NaN
#
#        Blood_Group Marital_Status  Phone_Number               Email  ...  \
# ...

# %%
# 9.	Check how many missing values exist per column
# Note: Identify columns that need data cleaning or filling.
df1.isnull().sum()
# Out:
# Patient_ID                0
# First_Name                0
# Last_Name                 0
# Gender                    0
# Age                       0
# Date_of_Birth             0
# Blood_Group               0
# Marital_Status            0
# Phone_Number              0
# Email                     0
# Address                   0
# City                      0
# State                     0
# Country                   0
# Pincode                   0
# Height_cm                 0
# Weight_kg                 0
# BMI                       0
# Smoking_Status            0
# Alcohol_Consumption       0
# Chronic_Condition      4009
# Primary_Doctor_ID         0
# Insurance_Provider        0
# Insurance_Policy_No       0
# Registration_Date         0
# dtype: int64

# %%
# 10.	Check if the dataset contains duplicate Patient_IDs
# Note: Patient_ID should be unique; duplicates indicate data quality issues.
df1.duplicated(subset = ['Patient_ID']).sum()
# Out:
# np.int64(0)

# %%
# 11.	Find the total number of unique patients
# Note: Use Patient_ID to verify uniqueness.
df1.Patient_ID.nunique()
# Out:
# 20000

# %%
# 12.	Display memory usage of the DataFrame
# Note: Important when working with large healthcare datasets.
df1.memory_usage()
# Out:
# Index                     132
# Patient_ID             160000
# First_Name             160000
# Last_Name              160000
# Gender                 160000
# Age                    160000
# Date_of_Birth          160000
# Blood_Group            160000
# Marital_Status         160000
# Phone_Number           160000
# Email                  160000
# Address                160000
# City                   160000
# State                  160000
# Country                160000
# Pincode                160000
# Height_cm              160000
# Weight_kg              160000
# BMI                    160000
# Smoking_Status         160000
# Alcohol_Consumption    160000
# Chronic_Condition      160000
# Primary_Doctor_ID      160000
# Insurance_Provider     160000
# Insurance_Policy_No    160000
# Registration_Date      160000
# dtype: int64

# %%
# 13.	Sort patients by Age in descending order
# Note: Oldest patients should appear first.
df1.sort_values(by = 'Age', ascending = False)
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 8399      P08400      Sneha     Singh  Female   60    1965-08-07         AB-
# 19        P00020      Pooja     Joshi  Female   60    1965-07-26          B+
# 14971     P14972      Sneha    Sharma  Female   60    1965-04-13          A-
# 1148      P01149     Anjali     Verma    Male   60    1965-04-25          O+
# 1149      P01150       Neha     Gupta    Male   60    1965-04-25          A+
# ...          ...        ...       ...     ...  ...           ...         ...
# 13482     P13483     Anjali     Singh  Female   27    1998-01-11          A+
# 8050      P08051      Rahul     Patil  Female   27    1998-01-10          B-
# 16179     P16180     Anjali     Patil    Male   27    1998-01-18          A+
# 16191     P16192     Anjali     Gupta    Male   27    1998-01-18         AB-
# 3456      P03457      Vikas     Verma  Female   27    1998-01-16          A+
#
# ...

# %%
# 14.	Sort patients by Registration_Date in ascending order
# Note: Earliest registered patients should appear first.
df1.sort_values(by = 'Registration_Date', ascending = True)
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 17264     P17265       Amit      Iyer    Male   46    1979-12-10          O+
# 16781     P16782       Amit     Gupta    Male   35    1990-07-15          A-
# 3817      P03818      Vikas  Kulkarni    Male   37    1988-10-20          O+
# 3955      P03956      Rohan     Mehta  Female   44    1981-03-03         AB-
# 18676     P18677      Rohan     Mehta  Female   34    1991-11-30          B+
# ...          ...        ...       ...     ...  ...           ...         ...
# 9220      P09221     Anjali    Sharma    Male   40    1985-07-24          B+
# 934       P00935     Suresh     Gupta  Female   52    1973-01-17          O-
# 4328      P04329     Kavita     Mehta  Female   47    1978-07-01          A+
# 1431      P01432       Amit  Kulkarni  Female   35    1990-11-21          A-
# 11977     P11978      Rahul      Iyer    Male   55    1970-06-03         AB-
#
# ...

# %%
# 15.	Display random 10 patient records
# Note: Random sampling helps quick data inspection.
df1.sample(10)
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 3682      P03683      Rohan     Verma    Male   41    1984-05-11          A+
# 19415     P19416      Vikas  Kulkarni    Male   59    1966-01-27         AB+
# 13912     P13913       Amit     Mehta  Female   40    1985-10-13          O-
# 14280     P14281     Anjali      Iyer    Male   59    1966-12-08          O+
# 18968     P18969     Suresh     Patil    Male   58    1967-01-12          O-
# 3231      P03232      Rahul     Patil  Female   56    1969-02-03          A+
# 6297      P06298      Vikas     Gupta    Male   43    1982-04-03          A-
# 5728      P05729      Rahul     Verma  Female   28    1997-05-14          A+
# 14582     P14583       Amit     Verma    Male   39    1986-07-29          O+
# 6811      P06812       Amit     Joshi    Male   51    1974-06-10          B+
#
#       Marital_Status  Phone_Number               Email  ... Height_cm  \
# ...

# %%
# 🔹 SECTION 2: FILTERING & CONDITIONAL SELECTION (16–35)
# 16.	Find all male patients
# 📝 Note: Filter rows where Gender equals "Male".
df1['Gender'] == 'Male'
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 19995     True
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Name: Gender, Length: 20000, dtype: bool

# %%
# 17.	Find all female patients above 50 years
# 📝 Note: Apply two conditions: Gender = Female AND Age > 50.
df1[(df1['Gender'] == 'Female') & (df1['Age'] > 50)]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 7         P00008      Vikas     Gupta  Female   59    1966-03-23         AB+
# 10        P00011      Sneha     Verma  Female   51    1974-03-31          O-
# 12        P00013      Vikas     Verma  Female   56    1969-08-17          A-
# 19        P00020      Pooja     Joshi  Female   60    1965-07-26          B+
# 29        P00030      Rahul     Singh  Female   56    1969-11-16          A+
# ...          ...        ...       ...     ...  ...           ...         ...
# 19968     P19969     Suresh     Singh  Female   56    1969-09-07         AB-
# 19983     P19984      Rahul      Iyer  Female   54    1971-07-06          A+
# 19992     P19993      Rahul      Iyer  Female   58    1967-01-17         AB-
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
# ...

# %%
# 18.	Find patients from Pune city
# 📝 Note: Match exact city name in City column.
df1['City'] == 'Pune'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Name: City, Length: 20000, dtype: bool

# %%
# 19.	Find patients suffering from Diabetes
# 📝 Note: Use Chronic_Condition column and filter "Diabetes".
df1['Chronic_Condition'] == 'Diabetes'
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Name: Chronic_Condition, Length: 20000, dtype: bool

# %%
# 20.	Find patients who are smokers
# 📝 Note: Filter Smoking_Status column for "Yes".
df1['Smoking_Status'] == 'Yes'
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996     True
# 19997    False
# 19998     True
# 19999     True
# Name: Smoking_Status, Length: 20000, dtype: bool

# %%
# 21.	Find patients who consume alcohol occasionally
# 📝 Note: Match Alcohol_Consumption = "Occasionally".
df1['Alcohol_Consumption'] == 'Occasionally'
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 19995     True
# 19996     True
# 19997     True
# 19998     True
# 19999     True
# Name: Alcohol_Consumption, Length: 20000, dtype: bool

# %%
# 22.	Find patients with BMI greater than 30
# 📝 Note: BMI > 30 is considered obese (high risk).
df2['BMI'] > 30
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 139995    False
# 139996    False
# 139997    False
# 139998     True
# 139999    False
# Name: BMI, Length: 140000, dtype: bool

# %%
# 23.	Find patients with no chronic condition
# 📝 Note: Chronic_Condition value should be "None".
df1['Chronic_Condition'] == 'None'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Name: Chronic_Condition, Length: 20000, dtype: bool

# %%
# 24.	Find patients registered after 2023
# 📝 Note: Convert Registration_Date to datetime and compare year > 2023.
df1['Registration_Date']=pd.to_datetime(df1['Registration_Date'])
df1[df1['Registration_Date'].dt.year > 2023]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 18        P00019      Rahul      Iyer  Female   50    1975-05-13          O-
# 46        P00047      Vikas     Joshi  Female   41    1984-03-04          A+
# 184       P00185      Rohan     Patil    Male   40    1985-12-04          B-
# 323       P00324      Rohan     Patil  Female   58    1967-01-23          A+
# 326       P00327     Anjali     Verma  Female   36    1989-11-14          O-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19825     P19826      Rahul     Patil    Male   58    1967-11-07          B+
# 19838     P19839      Rahul     Mehta    Male   53    1972-01-25          B+
# 19870     P19871      Pooja     Patil    Male   60    1965-06-04         AB-
# 19924     P19925      Vikas    Sharma  Female   48    1977-05-23          A+
# 19996     P19997      Vikas     Verma  Female   57    1968-10-05         AB-
#
# ...

# %%
# 25.	Find patients with blood group O+
# 📝 Note: Exact string match "O+".
df1['Blood_Group'] == 'o+'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Name: Blood_Group, Length: 20000, dtype: bool

# %%
# 26.	Find patients insured under Star Health
# 📝 Note: Filter Insurance_Provider column.
df1['Insurance_Provider'] == 'Star Health'
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997     True
# 19998    False
# 19999    False
# Name: Insurance_Provider, Length: 20000, dtype: bool

# %%
df1.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 20000 entries, 0 to 19999
# Series name: Registration_Date
# Non-Null Count  Dtype
# --------------  -----
# 20000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 156.4 KB

# %%
# 27.	Find patients whose height is above 175 cm
# 📝 Note: Numeric filtering using Height_cm column.
df1['Height_cm'] == 175
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Name: Height_cm, Length: 20000, dtype: bool

# %%
# 28.	Find patients aged between 30 and 45
# 📝 Note: Age >= 30 AND Age <= 45.
df1[(df1['Age'] >= 30) & (df1['Age'] <= 45)]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 4         P00005      Rohan     Verma    Male   41    1984-02-11          A-
# 6         P00007     Suresh      Nair    Male   42    1983-02-17          B-
# 8         P00009     Kavita     Mehta  Female   30    1995-03-30          A+
# ...          ...        ...       ...     ...  ...           ...         ...
# 19989     P19990      Pooja     Joshi    Male   35    1990-07-24         AB-
# 19991     P19992      Vikas    Sharma  Female   39    1986-11-17         AB-
# 19993     P19994     Anjali     Joshi  Female   43    1982-04-25          O-
# 19995     P19996     Anjali     Mehta    Male   36    1989-10-07          A-
# 19998     P19999       Amit    Sharma  Female   43    1982-07-30          A-
#
# ...

# %%
# 29.	Find patients from Mumbai OR Pune
# 📝 Note: Use OR condition or isin().
df1[(df1['City'] == 'Mumbai') | (df1['City'] == 'Pune')]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 1         P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 3         P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 6         P00007     Suresh      Nair    Male   42    1983-02-17          B-
# 7         P00008      Vikas     Gupta  Female   59    1966-03-23         AB+
# 10        P00011      Sneha     Verma  Female   51    1974-03-31          O-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19987     P19988      Rohan     Joshi    Male   46    1979-05-02          B-
# 19988     P19989      Vikas     Patil    Male   54    1971-07-25         AB-
# 19989     P19990      Pooja     Joshi    Male   35    1990-07-24         AB-
# 19991     P19992      Vikas    Sharma  Female   39    1986-11-17         AB-
# 19993     P19994     Anjali     Joshi  Female   43    1982-04-25          O-
#
# ...

# %%
# 30.	Find patients who are married and diabetic
# 📝 Note: Marital_Status = Married AND Chronic_Condition = Diabetes.
df1[(df1['Marital_Status'] == 'Married') & (df1['Chronic_Condition'] == 'Diabetes')]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 3         P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 13        P00014     Suresh     Mehta  Female   39    1986-05-10          A-
# 15        P00016      Pooja      Iyer    Male   41    1984-04-04         AB-
# 30        P00031      Vikas     Patil    Male   46    1979-10-08          O-
# 34        P00035       Amit      Nair    Male   46    1979-02-01          O-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19953     P19954      Sneha      Iyer    Male   55    1970-10-26          A-
# 19977     P19978      Rahul     Gupta    Male   43    1982-07-27         AB-
# 19983     P19984      Rahul      Iyer  Female   54    1971-07-06          A+
# 19989     P19990      Pooja     Joshi    Male   35    1990-07-24         AB-
# 19993     P19994     Anjali     Joshi  Female   43    1982-04-25          O-
#
# ...

# %%
# 31.	Find patients whose email contains “gmail”
# 📝 Note: Use string methods for partial match.
df1['Email'].str.contains('gmail')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# 19999    False
# Name: Email, Length: 20000, dtype: bool

# %%
# 32.	Find patients whose Patient_ID starts with “P1”
# 📝 Note: Prefix-based filtering.
df1['Patient_ID'].str.startswith('P1')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19995     True
# 19996     True
# 19997     True
# 19998     True
# 19999    False
# Name: Patient_ID, Length: 20000, dtype: bool

# %%
# 33.	Find patients with weight above average weight
# 📝 Note: First calculate average weight, then filter.
df1['Weight_kg'] > df1['Weight_kg'].mean()
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 19995    False
# 19996    False
# 19997    False
# 19998     True
# 19999     True
# Name: Weight_kg, Length: 20000, dtype: bool

# %%
# 34.	Find patients having Asthma or Thyroid
# 📝 Note: OR condition on Chronic_Condition column.
df1[(df1['Chronic_Condition'] == 'Asthma') | (df1['Chronic_Condition'] == 'Thyroid')]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0         P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 2         P00003       Neha     Joshi    Male   56    1969-12-29         AB-
# 8         P00009     Kavita     Mehta  Female   30    1995-03-30          A+
# 11        P00012      Rahul     Mehta  Female   50    1975-11-26         AB-
# 14        P00015     Suresh     Gupta    Male   50    1975-10-23          B-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19978     P19979     Kavita     Gupta    Male   42    1983-09-27          O+
# 19981     P19982      Vikas     Singh  Female   42    1983-10-27          O+
# 19990     P19991      Vikas     Joshi    Male   55    1970-05-20          O+
# 19991     P19992      Vikas    Sharma  Female   39    1986-11-17         AB-
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
# ...

# %%
# 35.	Find patients whose BMI is below 18.5
# 📝 Note: BMI < 18.5 indicates underweight.

# %%
# SECTION 3: AGGREGATION & GROUPBY (36–55)
# 36.	Find the average age of patients
# 📝 Note: Use mean aggregation on Age column.
df1['Age'].mean()
# Out:
# np.float64(43.88275)

# %%
# 37.	Find average BMI by gender
# 📝 Note: Group by Gender and calculate mean BMI.
df1.groupby('Gender')['BMI'].mean()
# Out:
# Gender
# Female    25.939014
# Male      25.915914
# Name: BMI, dtype: float64

# %%
# 38.	Count number of patients per city
# 📝 Note: Group by City and count rows.
df1.groupby('City').value_counts()
# Out:
# City    Patient_ID  First_Name  Last_Name  Gender  Age  Date_of_Birth  Blood_Group  Marital_Status  Phone_Number  Email               Address        State        Country  Pincode  Height_cm  Weight_kg  BMI   Smoking_Status  Alcohol_Consumption  Chronic_Condition  Primary_Doctor_ID  Insurance_Provider  Insurance_Policy_No  Registration_Date
# Mumbai  P00004      Anjali      Patil      Male    47   1978-12-04     A-           Married         9196136323    user4@mail.com      Local Address  Maharashtra  India    402003   162        60         22.9  No              No                   Diabetes           D101               Reliance General    POL912134            2020-05-17           1
# ...

# %%
# 39.	Count number of patients per chronic condition
# 📝 Note: Shows disease distribution.
df1.groupby('Chronic_Condition')['Patient_ID'].count()
# Out:
# Chronic_Condition
# Asthma          3998
# Diabetes        4014
# Hypertension    3965
# Thyroid         4014
# Name: Patient_ID, dtype: int64

# %%
# 40.	Find maximum age per city
# 📝 Note: Group by City and apply max on Age.
df1.groupby('City')['Age'].max()
# Out:
# City
# Mumbai         60
# Nagpur         60
# Nashik         60
# Navi Mumbai    60
# Pune           60
# Name: Age, dtype: int64

# %%
# 41.	Find minimum BMI per gender
# 📝 Note: Identify lowest BMI per gender group.
df1.groupby('Gender')['BMI'].min()
# Out:
# Gender
# Female    15.4
# Male      15.4
# Name: BMI, dtype: float64

# %%
# 42.	Find average height per city
# 📝 Note: City-wise physical comparison.
df1.groupby('City')['Height_cm'].mean()
# Out:
# City
# Mumbai         164.782764
# Nagpur         165.090549
# Nashik         165.035218
# Navi Mumbai    165.071191
# Pune           165.030007
# Name: Height_cm, dtype: float64

# %%
# 43.	Find total patients per insurance provider
# 📝 Note: Count patients under each insurer.
df1.groupby('Insurance_Provider')['Patient_ID'].count()
# Out:
# Insurance_Provider
# HDFC Ergo              3942
# ICICI Lombard          3969
# New India Assurance    4077
# Reliance General       3976
# Star Health            4036
# Name: Patient_ID, dtype: int64

# %%
# 44.	Find city with highest number of patients
# 📝 Note: Sort aggregated counts.
df1.groupby('City')['Patient_ID'].value_counts()
# Out:
# City    Patient_ID
# Mumbai  P00002        1
#         P00004        1
#         P00021        1
#         P00027        1
#         P00038        1
#                      ..
# Pune    P19967        1
#         P19971        1
#         P19973        1
#         P19988        1
#         P19989        1
# Name: count, Length: 20000, dtype: int64

# %%
# 45.	Find average BMI per smoking status
# 📝 Note: Compare smokers vs non-smokers.
df1.groupby('Smoking_Status')['BMI'].mean()
# Out:
# Smoking_Status
# No     25.918135
# Yes    25.936532
# Name: BMI, dtype: float64

# %%
# 46.	Find number of patients per blood group
# 📝 Note: Useful for healthcare planning.
df1.groupby('Blood_Group')['Patient_ID'].count()
# Out:
# Blood_Group
# A+     2590
# A-     2493
# AB+    2565
# AB-    2417
# B+     2521
# B-     2505
# O+     2410
# O-     2499
# Name: Patient_ID, dtype: int64

# %%
# 47.	Find average age per marital status
# 📝 Note: Demographic insight.
df1.groupby('Marital_Status')['Age'].mean()
# Out:
# Marital_Status
# Married    43.895618
# Single     43.869951
# Name: Age, dtype: float64

# %%
# 48.	Find highest BMI per chronic condition
# 📝 Note: Identify extreme risk cases.
df1.groupby('Chronic_Condition')['BMI'].max()
# Out:
# Chronic_Condition
# Asthma          40.0
# Diabetes        40.0
# Hypertension    40.0
# Thyroid         40.0
# Name: BMI, dtype: float64

# %%
# 49.	Find lowest weight per city
# 📝 Note: Detect outliers.
df1.groupby('City')['Weight_kg'].mean()
# Out:
# City
# Mumbai         69.951555
# Nagpur         69.882484
# Nashik         69.984375
# Navi Mumbai    69.998207
# Pune           70.060990
# Name: Weight_kg, dtype: float64

# %%
# 50.	Count patients registered per year
# 📝 Note: Extract year from Registration_Date.
df1.groupby(df1['Registration_Date'].dt.year)['Patient_ID'].count()
# Out:
# Registration_Date
# 2020    4944
# 2021    4811
# 2022    4837
# 2023    4838
# 2024     570
# Name: Patient_ID, dtype: int64

# %%
# 51.	Find insurance provider with maximum patients
# 📝 Note: Rank insurance providers.
df1.groupby('Insurance_Provider')['Patient_ID'].count()
# Out:
# Insurance_Provider
# HDFC Ergo              3942
# ICICI Lombard          3969
# New India Assurance    4077
# Reliance General       3976
# Star Health            4036
# Name: Patient_ID, dtype: int64

# %%
# 52.	Find number of patients per doctor
# 📝 Note: Doctor workload analysis.
df1.groupby('Primary_Doctor_ID')['Patient_ID'].count()
# Out:
# Primary_Doctor_ID
# D100    1821
# D101    1789
# D102    1841
# D103    1846
# D104    1820
# D105    1809
# D106    1733
# D107    1857
# D108    1852
# D109    1806
# D110    1826
# Name: Patient_ID, dtype: int64

# %%
# 53.	Find average BMI per doctor
# 📝 Note: Care quality insight.
df1.groupby('Primary_Doctor_ID')['BMI'].mean()
# Out:
# Primary_Doctor_ID
# D100    25.969577
# D101    25.832700
# D102    26.107496
# D103    26.128277
# D104    25.819615
# D105    25.869707
# D106    25.856145
# D107    25.877975
# D108    26.002376
# D109    25.864673
# D110    25.860843
# Name: BMI, dtype: float64

# %%
# 54. find total patients with chronic conditions
# 📝 note: exclude "none".
df1[df1['Chronic_Condition'].notna()].groupby('Chronic_Condition')['Patient_ID'].count()
# Out:
# Chronic_Condition
# Asthma          3998
# Diabetes        4014
# Hypertension    3965
# Thyroid         4014
# Name: Patient_ID, dtype: int64

# %%
# 55.	Find percentage of smokers vs non-smokers
# 📝 Note: Convert counts into percentages.
df1['Smoking_Status'].value_counts(normalize=True) * 100
# Out:
# Smoking_Status
# No     50.18
# Yes    49.82
# Name: proportion, dtype: float64

# %%
# 🔹 SECTION 4: DATA TRANSFORMATION (56–75)
# 56.	Create a new column Age_Group (Young, Adult, Senior)
# 📝 Note:
# o	Age 5–25 → Young
# o	Age 26–50 → Adult
# o	Age Above 50 → Senior
df1['Age_Group'] = df1['Age'].apply(lambda x: 'Young' if 5 <= x <= 25 else ('Adult' if 26 <= x <= 50 else 'Senior'))

# %%
# 57.	Create a column Risk_Level based on BMI
# 📝 Note:
# o	BMI < 18.5 → Low
# o	BMI 18.5–25 → Normal
# o	BMI 25–30 → Medium
# o	BMI > 30 → High
df1['Risk_Level'] = df1['BMI'].apply(lambda i: 'Low' if i < 18.5 else ('Normal' if 18.5 <= i <= 25 else ('Medium' if 25 < i <= 30 else 'High')))

# %%
# 58.	Convert Registration_Date to datetime
# 📝 Note: Required before extracting year or month.
df1['Registration_Date'] = pd.to_datetime(df1['Registration_Date'])

# %%
# 59.	Extract Registration Year
# 📝 Note: Create a new column storing year only.
df1['Registration_Year']=df1['Registration_Date'].dt.year

# %%
# 60.	Extract Registration Month
# 📝 Note: Month should be numeric (1–12).
df1['Registration_Month']=df1['Registration_Date'].dt.month

# %%
# 61.	Create column Is_Senior (Age > 60)
# 📝 Note: True if Age > 60, else False.
df1['Is_Senior']=df1['Age'].apply(lambda i: 'Yes' if i > 60 else 'No')

# %%
# 62.	Create column High_Risk_Patient
# 📝 Note:
# o	BMI > 30
# o	AND Chronic_Condition ≠ "None"
# Create column with True/False based on conditions
df1['High_Risk_Patient'] = (df1['BMI'] > 30) & (df1['Chronic_Condition'] != 'None')

# %%
# 63.	Convert Gender column to category type
# 📝 Note: Improves memory efficiency.
df1['Gender'] = pd.Categorical(df1['Gender'])

# %%
# 64.	Convert Blood_Group column to category
# 📝 Note: Limited unique values → ideal for category.
df1['Blood_Group'] = pd.Categorical(df1['Gender'])

# %%
# 65.	Rename column Phone_Number to Contact_Number
# 📝 Note: Use rename operation.
df1 = df1.rename(columns = {'Phone_Number' :'Contact_Number'})

# %%
# 66.	Drop Email column
# 📝 Note: Remove unnecessary or sensitive data.
df1.drop('Email',axis=1,inplace=True)

# %%
# 67.	Fill missing Chronic_Condition with “Unknown”
# 📝 Note: Handle missing values.
df1['Chronic_Condition'] = df1['Chronic_Condition'].fillna('Unknown')

# %%
# 68.	Create BMI_Category
# 📝 Note:
# o	<18.5 → Underweight
# o	18.5–25 → Normal
# o	25–30 → Overweight
# o	30 → Obese
df1['BMI_Category'] = df1['BMI'].apply(lambda i: 'Underweight' if i < 18.5 else ('Normal' if 18.5 <= i <= 25 else ('Overweight' if 25 < i <= 30 else 'Obese')))

# %%
# 69.	Normalize Height column
# 📝 Note: Scale values between 0 and 1.
df1['Height_cm'] = (df1['Height_cm'] - df1['Height_cm'].min()) / (df1['Height_cm'].max() - df1['Height_cm'].min())
df1['Height_cm']
# Out:
# 0        0.166667
# 1        0.600000
# 2        0.633333
# 3        0.400000
# 4        0.033333
#            ...
# 19995    0.766667
# 19996    0.800000
# 19997    0.566667
# 19998    0.233333
# 19999    0.166667
# Name: Height_cm, Length: 20000, dtype: float64

# %%
# 70.	Standardize Weight column
# 📝 Note: Mean = 0, Standard Deviation = 1.
# Apply Z-score standardization: (value - mean) / std
df1['Weight_kg'] = (df1['Weight_kg'] - df1['Weight_kg'].mean()) / df1['Weight_kg'].std()
df1['Weight_kg']
# Out:
# 0       -1.688900
# 1        0.340240
# 2        0.086598
# 3       -0.843425
# 4        1.439358
#            ...
# 19995   -0.589782
# 19996   -0.758877
# 19997   -1.266162
# 19998    0.086598
# 19999    1.608453
# Name: Weight_kg, Length: 20000, dtype: float64

# %%
# 71.	Add column Insurance_Status (Yes/No)
# 📝 Note: Yes if Insurance_Provider exists, else No.
df1['Insurance_Status'] = df1['Insurance_Provider'].apply(lambda i: 'Yes' if pd.notna(i) else 'No')

# %%
# 72.	Create column Patient_Location
# 📝 Note: Combine City and State with separator.
df1['Patient_Location'] = df1['City'] + ',' + df1['State']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Patient_ID           20000 non-null  object
#  1   First_Name           20000 non-null  object
#  2   Last_Name            20000 non-null  object
#  3   Gender               20000 non-null  category
#  4   Age                  20000 non-null  int64
#  5   Date_of_Birth        20000 non-null  object
#  6   Blood_Group          20000 non-null  category
#  7   Marital_Status       20000 non-null  object
#  8   Contact_Number       20000 non-null  int64
#  9   Email                20000 non-null  object
#  10  Address              20000 non-null  object
#  11  City                 20000 non-null  object
#  12  State                20000 non-null  object
#  13  Country              20000 non-null  object
#  14  Pincode              20000 non-null  int64
# ...

# %%
# 73.	Sort patients by BMI descending
# 📝 Note: Highest BMI first.
df1.sort_values(by = 'BMI', ascending = False)
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 17826     P17827     Kavita    Sharma  Female   40    1985-08-05         AB+
# 10001     P10002     Anjali     Singh  Female   56    1969-05-19          B+
# 10369     P10370      Pooja     Singh    Male   34    1991-10-01          O-
# 7256      P07257      Vikas      Iyer    Male   38    1987-02-22          B+
# 1953      P01954      Pooja     Patil    Male   54    1971-07-26          B+
# ...          ...        ...       ...     ...  ...           ...         ...
# 10472     P10473      Sneha     Gupta    Male   52    1973-05-06          B-
# 9592      P09593      Pooja     Verma  Female   34    1991-12-21         AB+
# 19194     P19195       Neha     Mehta    Male   35    1990-11-15         AB-
# 15514     P15515      Rohan     Mehta  Female   47    1978-09-16         AB-
# 19909     P19910     Kavita      Nair    Male   50    1975-07-07          O-
#
# ...

# %%
# 74.	Reset index after sorting
# 📝 Note: Clean index after rearranging rows.
df1.reset_index(drop=True, inplace=True)

# %%
# 75.	Select top 10 highest BMI patients
# 📝 Note: Used for high-risk analysis.
df1.sort_values(by = 'BMI', ascending = False).head(10)
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 17826     P17827     Kavita    Sharma  Female   40    1985-08-05         AB+
# 10001     P10002     Anjali     Singh  Female   56    1969-05-19          B+
# 10369     P10370      Pooja     Singh    Male   34    1991-10-01          O-
# 7256      P07257      Vikas      Iyer    Male   38    1987-02-22          B+
# 1953      P01954      Pooja     Patil    Male   54    1971-07-26          B+
# 2913      P02914      Rahul     Joshi  Female   55    1970-06-27          O+
# 14250     P14251      Rohan     Patil  Female   40    1985-06-23         AB-
# 14268     P14269      Rahul     Singh    Male   35    1990-07-22          A-
# 5024      P05025     Anjali      Iyer  Female   57    1968-11-13          O-
# 17251     P17252     Anjali     Joshi  Female   48    1977-10-07          O-
#
#       Marital_Status  Phone_Number               Email  ...   BMI  \
# ...

# %%
# 🔹 SECTION 5: ADVANCED / ANALYTICAL QUESTIONS (76–90)
# 76.	Find top 5 cities with highest average BMI
# 📝 Note: Group → Mean → Sort → Top 5.
df1.groupby('City')['BMI'].mean().sort_values(ascending=False).head(5)
# Out:
# City
# Mumbai         25.984345
# Pune           25.945328
# Nashik         25.922247
# Navi Mumbai    25.911626
# Nagpur         25.873850
# Name: BMI, dtype: float64

# %%
# 77.	Find bottom 5 cities with lowest average BMI
# 📝 Note: Ascending order.
df1.groupby('City')['BMI'].mean().sort_values(ascending=True).head(5)
# Out:
# City
# Nagpur         25.873850
# Navi Mumbai    25.911626
# Nashik         25.922247
# Pune           25.945328
# Mumbai         25.984345
# Name: BMI, dtype: float64

# %%
# 78.	Find patients at high cardiovascular risk
# 📝 Note:
# o	Age > 50
# o	BMI > 30
# o	Chronic condition present
df1['high_cardiovascular_risk'] = (df1['Age'] > 50) & (df1['BMI'] > 30) & (df1['Chronic_Condition'].notna())
df1[df1['high_cardiovascular_risk']]
# Out:
#       Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 19        P00020      Pooja     Joshi  Female   60    1965-07-26          B+
# 31        P00032      Rohan      Iyer  Female   59    1966-02-21          A+
# 99        P00100     Suresh      Iyer    Male   52    1973-10-05          A-
# 116       P00117     Suresh  Kulkarni  Female   59    1966-06-02         AB+
# 144       P00145       Neha     Gupta    Male   54    1971-06-04          A-
# ...          ...        ...       ...     ...  ...           ...         ...
# 19938     P19939       Amit    Sharma    Male   52    1973-07-21          O-
# 19945     P19946     Suresh     Mehta  Female   59    1966-03-31          A+
# 19974     P19975      Pooja      Iyer    Male   52    1973-05-29          A+
# 19994     P19995     Suresh     Singh    Male   58    1967-01-14         AB+
# 19999     P20000      Pooja     Gupta  Female   58    1967-02-17          O-
#
# ...

# %%
# 79.	Find doctor handling maximum chronic patients
# 📝 Note: Filter chronic patients, then group by doctor.
chronic_df = df1[df1['Chronic_Condition'] == 'Yes']
top_doctor = chronic_df['Primary_Doctor_ID'].value_counts().max()

# %%
df1.groupby(df1['Chronic_Condition'] == 'Yes')['Primary_Doctor_ID'].value_counts().max()
# Out:
# 1857

# %%
# 80.	Find insurance provider covering most senior citizens
# 📝 Note: Senior = Age > 60.
df1.groupby('Insurance_Provider')['Age'].max()
# Out:
# Insurance_Provider
# HDFC Ergo              60
# ICICI Lombard          60
# New India Assurance    60
# Reliance General       60
# Star Health            60
# Name: Age, dtype: int64

# %%
# 81.	Find patients eligible for lifestyle counseling
# 📝 Note: BMI > 25 OR Smoking = Yes OR Alcohol = Occasionally.
df1['lifestyle_counseling'] = (df1['BMI'] > 25) | (df1['Smoking_Status'] == 'Yes') | (df1['Alcohol_Consumption'] == 'Occasionally')

# %%
# 82.	Identify potential ICU-risk patients
# 📝 Note: Age > 65 AND BMI > 30 AND chronic condition present.
df1['ICU-risk_ patients'] = (df1['Age'] > 65) & (df1['BMI'] > 30) & (df1['Chronic_Condition'].notna())

# %%
# 83.	Find correlation between Age and BMI
# 📝 Note: Measures relationship strength.
df1['Age'].corr(df1['BMI'])
# Out:
# np.float64(-0.006068530558057469)

# %%
# 84.	Detect BMI outliers using IQR
# 📝 Note:
# o	Lower bound = Q1 − 1.5×IQR
# o	Upper bound = Q3 + 1.5×IQR
# 1. Calculate Q1 (25th percentile) and Q3 (75th percentile)
q1 = df1['BMI'].quantile(0.25)
q3 = df1['BMI'].quantile(0.75)

# 2. Calculate the Interquartile Range (IQR)
iqr = q3 - q1

# 3. Determine upper and lower bounds
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# 4. Filter out the outliers
bmi_outliers = df1[(df1['BMI'] < lower_bound) | (df1['BMI'] > upper_bound)]

print(f"Lower Bound: {lower_bound:.2f}, Upper Bound: {upper_bound:.2f}")
print(f"Total outliers detected: {len(bmi_outliers)}")
print(bmi_outliers[['Patient_ID', 'BMI']])
# Out:
# Lower Bound: 10.25, Upper Bound: 41.05
# Total outliers detected: 0
# Empty DataFrame
# Columns: [Patient_ID, BMI]
# Index: []

# %%
# 85.	Create pivot table of Gender vs Chronic Condition
# 📝 Note: Rows = Gender, Columns = Chronic_Condition.

# %%
# 86.	Create pivot of City vs Smoking_Status
# 📝 Note: Cross-tab city and smoking habits.
city_smoking_total = pd.crosstab(index=df1['City'], columns=df1['Smoking_Status'], normalize=True)
print(city_smoking_total)
# Out:
# Smoking_Status       No      Yes
# City
# Mumbai          0.09780  0.09830
# Nagpur          0.10165  0.10045
# Nashik          0.10270  0.09890
# Navi Mumbai     0.09755  0.09770
# Pune            0.10210  0.10285

# %%
# 87.	Calculate rolling average BMI by age
# 📝 Note: Use window size (e.g., 5).
age_means = df1.groupby('Age')['BMI'].mean().reset_index()
age_means['Rolling_Avg_BMI'] = age_means['BMI'].rolling(window=5, min_periods=1).mean()

# %%
# 88.	Rank patients by BMI within each city
# 📝 Note: Ranking should reset per city.
df1.groupby('City')['BMI'].rank(method='dense', ascending=False)
# Out:
# 0        172.0
# 1        119.0
# 2        132.0
# 3        152.0
# 4         10.0
#          ...
# 19995    170.0
# 19996    179.0
# 19997    183.0
# 19998     92.0
# 19999     20.0
# Name: BMI, Length: 20000, dtype: float64

# %%
df1.head()
# Out:
#   Patient_ID First_Name Last_Name  Gender  Age Date_of_Birth Blood_Group  \
# 0     P00001     Suresh      Iyer    Male   38    1987-11-23          B+
# 1     P00002       Amit    Sharma  Female   38    1987-04-28          B+
# 2     P00003       Neha     Joshi    Male   56    1969-12-29         AB-
# 3     P00004     Anjali     Patil    Male   47    1978-12-04          A-
# 4     P00005      Rohan     Verma    Male   41    1984-02-11          A-
#
#   Marital_Status  Phone_Number           Email  ... Height_cm Weight_kg   BMI  \
# 0         Single    9698790602  user1@mail.com  ...       155        50  20.8
# 1        Married    9762620912  user2@mail.com  ...       168        74  26.2
# 2         Single    9522528550  user3@mail.com  ...       169        71  24.9
# 3        Married    9196136323  user4@mail.com  ...       162        60  22.9
# 4         Single    9644918514  user5@mail.com  ...       151        87  38.2
#
# ...

# %%
# 89.	Find percentile rank of BMI
# 📝 Note: Shows relative BMI position.
df1['BMI'].rank(pct=True)
# Out:
# 0        0.184125
# 1        0.538275
# 2        0.452000
# 3        0.321975
# 4        0.990525
#            ...
# 19995    0.195950
# 19996    0.144375
# 19997    0.123325
# 19998    0.708675
# 19999    0.977850
# Name: BMI, Length: 20000, dtype: float64

# %%
# 90.	Export cleaned DataFrame to CSV
# 📝 Note: Final output after transformations.
df1.to_csv("Cleaned_Hostital_Dataset",index=False)

# %% [markdown]
# ## ***Questions on Employee Database:***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/employee_data.csv")
df
# Out:
#      First Name  Last Name  Department  Gender       Location Joining Date  \
# 0          Cory  Schroeder     Finance    Male  San Francisco   2023-11-16
# 1    Jacqueline      Bowen          IT  Female  San Francisco   2023-06-28
# 2        Rhonda   Gonzalez   Marketing    Male         Boston   2020-05-13
# 3         Bryan      Clark       Sales    Male         Boston   2016-05-24
# 4          Mary   Mcdonald  Operations   Other        Houston   2020-02-20
# ..          ...        ...         ...     ...            ...          ...
# 145      Janice     Torres          HR  Female        Houston   2021-02-16
# 146        Paul      Green          IT  Female    Los Angeles   2017-12-26
# 147      Teresa     Martin     Finance    Male          Miami   2022-01-10
# 148       Robyn   Peterson          HR  Female       New York   2024-01-06
# 149     Heather  Hernandez   Marketing    Male         Boston   2020-12-27
#
#     Joining Month           City    Country  Salary  Bonus
# ...

# %%
# 1.	Create a bar chart showing the number of employees in each department.
a = df.groupby('Department')['First Name'].count()
plt.figure(figsize=(8,4))

a.plot(kind='bar',color = ['Skyblue'])

plt.title('Number of Employees in Each Department',color = 'Red')
plt.xlabel('Department')
plt.ylabel('Number of Employees')
plt.xticks(rotation=30)

plt.show()

# %%
# 2.	Plot a pie chart representing the distribution of employees by gender.
a = df.groupby('Gender')['First Name'].count()
a.plot(kind='pie',autopct="%1.2f%%")

plt.title('Distribution of Employees by Gender')
plt.ylabel('')

plt.xticks(rotation=20)
plt.show()

# %%
# 3.	Create a line chart showing the total salary paid per year.
df['Joining Year'] = pd.to_datetime(df['Joining Date']).dt.year
b = df.groupby('Joining Year')['Salary'].sum()
b.plot(kind='line')

plt.title('Total Salary Paid per Year')
plt.xlabel('Year')
plt.ylabel('Total Salary')
# Out:
# Text(0, 0.5, 'Total Salary')

# %%
# 4.	Plot a scatter plot between salary and bonus to see their correlation.
a = df.groupby('Salary')['Bonus'].sum()

plt.figure(figsize=(5, 4))
sns.scatterplot(data=df, x="Salary", y="Bonus")

plt.title("Correlation Between Salary and Bonus")
plt.xlabel("Salary")
plt.ylabel("Bonus")
plt.show()

# %%
# 5.	Create a histogram for salary distribution across all employees.
# Clean column names just in case they have spaces
df.columns = df.columns.str.strip()

# Plot the distribution
plt.figure(figsize=(8, 5))
# Note: Capitalise 'Salary' if your column name uses a capital letter
sns.histplot(data=df, x="Salary", kde=True, bins=15)

# Add labels
plt.title("Salary Distribution Across Employees")
plt.xlabel("Salary")
plt.ylabel("Number of Employees")
plt.show()

# %%
# 6.	Plot a stacked bar chart showing the number of employees by department and gender.
# Clean column names just in case they have spaces
df.columns = df.columns.str.strip()

# Step 1: Count employees grouped by department and gender
# Change 'department' and 'gender' if your columns use capital letters
counts = df.groupby(["Department", "Gender"]).size().unstack(fill_value=0)

# Step 2: Plot the stacked bar chart
counts.plot(kind="bar", stacked=True, figsize=(8, 4))

# Step 3: Add labels and details
plt.title("Number of Employees by Department and Gender")
plt.xlabel("Department")
plt.ylabel("Number of Employees")
plt.xticks(rotation=45)  # Rotates department names so they are readable
plt.legend(title="Gender")
plt.tight_layout()  # Prevents labels from getting cut off
plt.show()
