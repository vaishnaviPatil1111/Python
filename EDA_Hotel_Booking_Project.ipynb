# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnaviPatil1111/Python/blob/main/EDA_Hotel_Booking_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Hotel Booking

# %% [markdown]
# ##### **Project Type**    - EDA

# %% [markdown]
# # **Project Summary -**
